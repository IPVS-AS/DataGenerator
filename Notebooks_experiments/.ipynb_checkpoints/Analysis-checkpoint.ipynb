# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Vergleich für unterschiedliche imbalance degrees
#
# Wir haben insgesamt 5 verschiede imbalance degrees, die wir im FOlgenden betrachten: very_low, low, normal, high und very_high.

# %% [markdown]
# ## Normal Imbalance
#
# Zunächst die Ergebnisse für normal imbalance, also die hardcoded Hierarchie ohne zusätzliche Änderungen.

# %%
normal_imb_df = pd.read_csv('../imbalance_degree/normal/result_split/gini_accuracy_all_runs.csv')
normal_imb_df["Method"] = normal_imb_df["Method"].apply(lambda x: "SPH+CPI" if x=="Tailored Approach" else x)
normal_imb_df["Run"] = 1

normal_imb_df[normal_imb_df["Method"] == "CPI"]
# Out:
#      R_e       A@e Method  gini  p value  Run  SPH Executed  info loss  \
# 20     1  0.323333    CPI   0.3      0.7    1           NaN        NaN
# 21     2  0.440000    CPI   0.3      0.7    1           NaN        NaN
# 22     3  0.530000    CPI   0.3      0.7    1           NaN        NaN
# 23     4  0.610000    CPI   0.3      0.7    1           NaN        NaN
# 24     5  0.653333    CPI   0.3      0.7    1           NaN        NaN
# ..   ...       ...    ...   ...      ...  ...           ...        ...
# 185    6  0.583333    CPI   0.4      0.9    1           NaN        NaN
# 186    7  0.636667    CPI   0.4      0.9    1           NaN        NaN
# 187    8  0.683333    CPI   0.4      0.9    1           NaN        NaN
# 188    9  0.700000    CPI   0.4      0.9    1           NaN        NaN
# 189   10  0.736667    CPI   0.4      0.9    1           NaN        NaN
#
#      SPH A@1  RF+B A@1  CPI A@1  Avg Acc SPH+CPI
# 20       NaN       NaN      NaN              NaN
# 21       NaN       NaN      NaN              NaN
# 22       NaN       NaN      NaN              NaN
# 23       NaN       NaN      NaN              NaN
# 24       NaN       NaN      NaN              NaN
# ..       ...       ...      ...              ...
# 185      NaN       NaN      NaN              NaN
# 186      NaN       NaN      NaN              NaN
# 187      NaN       NaN      NaN              NaN
# 188      NaN       NaN      NaN              NaN
# 189      NaN       NaN      NaN              NaN
#
# [90 rows x 12 columns]

# %%
normal_imb_df[normal_imb_df["R_e"]==1]
# Out:
#      R_e       A@e   Method  gini  p value  Run  SPH Executed  info loss  \
# 0      1  0.363333      SPH -1.00     -1.0  1.0          10.0       0.25
# 10     1  0.336667     RF+B -1.00     -1.0  1.0          10.0        NaN
# 20     1  0.323333      CPI   NaN      NaN  NaN           NaN        NaN
# 30     1  0.320000  SPH+CPI  0.30      0.7  1.0          10.0       0.25
# 40     1  0.306667      CPI   NaN      NaN  NaN           NaN        NaN
# 50     1  0.333333  SPH+CPI  0.30      0.8  1.0          10.0       0.25
# 60     1  0.243333      CPI   NaN      NaN  NaN           NaN        NaN
# 70     1  0.386667  SPH+CPI  0.30      0.9  1.0          10.0       0.25
# 80     1  0.323333      CPI   NaN      NaN  NaN           NaN        NaN
# 90     1  0.326667  SPH+CPI  0.35      0.7  1.0          10.0       0.25
# 100    1  0.306667      CPI   NaN      NaN  NaN           NaN        NaN
# 110    1  0.340000  SPH+CPI  0.35      0.8  1.0          10.0       0.25
# 120    1  0.243333      CPI   NaN      NaN  NaN           NaN        NaN
# 130    1  0.386667  SPH+CPI  0.35      0.9  1.0          10.0       0.25
# 140    1  0.323333      CPI   NaN      NaN  NaN           NaN        NaN
# 150    1  0.333333  SPH+CPI  0.40      0.7  1.0          10.0       0.25
# 160    1  0.306667      CPI   NaN      NaN  NaN           NaN        NaN
# 170    1  0.353333  SPH+CPI  0.40      0.8  1.0          10.0       0.25
# 180    1  0.243333      CPI   NaN      NaN  NaN           NaN        NaN
# 190    1  0.400000  SPH+CPI  0.40      0.9  1.0          10.0       0.25
#
#       SPH A@1  RF+B A@1   CPI A@1  Avg Acc SPH+CPI
# 0         NaN       NaN       NaN              NaN
# 10        NaN       NaN       NaN              NaN
# 20        NaN       NaN       NaN              NaN
# 30   0.363333  0.336667  0.323333         0.707667
# 40        NaN       NaN       NaN              NaN
# 50   0.363333  0.336667  0.306667         0.710667
# 60        NaN       NaN       NaN              NaN
# 70   0.363333  0.336667  0.243333         0.720333
# 80        NaN       NaN       NaN              NaN
# 90   0.363333  0.336667  0.323333         0.708333
# 100       NaN       NaN       NaN              NaN
# 110  0.363333  0.336667  0.306667         0.711333
# 120       NaN       NaN       NaN              NaN
# 130  0.363333  0.336667  0.243333         0.720333
# 140       NaN       NaN       NaN              NaN
# 150  0.363333  0.336667  0.323333         0.718333
# 160       NaN       NaN       NaN              NaN
# 170  0.363333  0.336667  0.306667         0.722333
# 180       NaN       NaN       NaN              NaN
# 190  0.363333  0.336667  0.243333         0.728000

# %%
# get run and parameters with maximum average accuracy
#normal_imb_df["Method"]
best_result = normal_imb_df[normal_imb_df["Avg Acc SPH+CPI"] == normal_imb_df["Avg Acc SPH+CPI"].max()]
#best_gini = best_result["gini"].values[0]
best_gini = 0.3
#best_p = best_result["p value"].values[0]
best_p = 0.8
best_run = best_result["Run"].values[0]


best_ta_methods = normal_imb_df[((normal_imb_df["gini"] ==best_gini) & (normal_imb_df["Run"] == best_run) & (normal_imb_df["p value"] == best_p))]
best_other_methods = normal_imb_df[(normal_imb_df["Run"] == best_run) & (normal_imb_df["gini"] == -1)]
best_all_methods = pd.concat([best_ta_methods, best_other_methods])
best_all_methods['A@e'] = best_all_methods['A@e']*100
best_all_methods
# Out:
#     R_e        A@e   Method  gini  p value  Run  SPH Executed  info loss  \
# 40    1  30.666667      CPI   0.3      0.8    1           NaN        NaN
# 41    2  41.333333      CPI   0.3      0.8    1           NaN        NaN
# 42    3  50.666667      CPI   0.3      0.8    1           NaN        NaN
# 43    4  56.333333      CPI   0.3      0.8    1           NaN        NaN
# 44    5  61.333333      CPI   0.3      0.8    1           NaN        NaN
# 45    6  65.333333      CPI   0.3      0.8    1           NaN        NaN
# 46    7  67.000000      CPI   0.3      0.8    1           NaN        NaN
# 47    8  71.666667      CPI   0.3      0.8    1           NaN        NaN
# 48    9  75.000000      CPI   0.3      0.8    1           NaN        NaN
# 49   10  78.000000      CPI   0.3      0.8    1           NaN        NaN
# 50    1  33.333333  SPH+CPI   0.3      0.8    1          10.0       0.25
# 51    2  53.000000  SPH+CPI   0.3      0.8    1          10.0       0.25
# 52    3  61.333333  SPH+CPI   0.3      0.8    1          10.0       0.25
# 53    4  72.333333  SPH+CPI   0.3      0.8    1          10.0       0.25
# 54    5  77.666667  SPH+CPI   0.3      0.8    1          10.0       0.25
# 55    6  79.333333  SPH+CPI   0.3      0.8    1          10.0       0.25
# 56    7  81.666667  SPH+CPI   0.3      0.8    1          10.0       0.25
# 57    8  82.666667  SPH+CPI   0.3      0.8    1          10.0       0.25
# 58    9  84.000000  SPH+CPI   0.3      0.8    1          10.0       0.25
# 59   10  85.333333  SPH+CPI   0.3      0.8    1          10.0       0.25
# 0     1  36.333333      SPH  -1.0     -1.0    1          10.0       0.25
# 1     2  56.000000      SPH  -1.0     -1.0    1          10.0       0.25
# 2     3  65.000000      SPH  -1.0     -1.0    1          10.0       0.25
# 3     4  72.666667      SPH  -1.0     -1.0    1          10.0       0.25
# 4     5  78.666667      SPH  -1.0     -1.0    1          10.0       0.25
# 5     6  80.666667      SPH  -1.0     -1.0    1          10.0       0.25
# 6     7  82.333333      SPH  -1.0     -1.0    1          10.0       0.25
# 7     8  83.000000      SPH  -1.0     -1.0    1          10.0       0.25
# 8     9  84.666667      SPH  -1.0     -1.0    1          10.0       0.25
# 9    10  85.333333      SPH  -1.0     -1.0    1          10.0       0.25
# 10    1  33.666667     RF+B  -1.0     -1.0    1          10.0        NaN
# 11    2  43.333333     RF+B  -1.0     -1.0    1          10.0        NaN
# 12    3  56.000000     RF+B  -1.0     -1.0    1          10.0        NaN
# 13    4  63.333333     RF+B  -1.0     -1.0    1          10.0        NaN
# 14    5  67.666667     RF+B  -1.0     -1.0    1          10.0        NaN
# 15    6  71.333333     RF+B  -1.0     -1.0    1          10.0        NaN
# 16    7  74.000000     RF+B  -1.0     -1.0    1          10.0        NaN
# 17    8  77.333333     RF+B  -1.0     -1.0    1          10.0        NaN
# 18    9  79.666667     RF+B  -1.0     -1.0    1          10.0        NaN
# 19   10  81.000000     RF+B  -1.0     -1.0    1          10.0        NaN
#
#      SPH A@1  RF+B A@1   CPI A@1  Avg Acc SPH+CPI imbalance
# 40       NaN       NaN       NaN              NaN    normal
# 41       NaN       NaN       NaN              NaN    normal
# 42       NaN       NaN       NaN              NaN    normal
# 43       NaN       NaN       NaN              NaN    normal
# 44       NaN       NaN       NaN              NaN    normal
# 45       NaN       NaN       NaN              NaN    normal
# 46       NaN       NaN       NaN              NaN    normal
# 47       NaN       NaN       NaN              NaN    normal
# 48       NaN       NaN       NaN              NaN    normal
# 49       NaN       NaN       NaN              NaN    normal
# 50  0.363333  0.336667  0.306667         0.710667    normal
# 51  0.363333  0.336667  0.306667         0.710667    normal
# 52  0.363333  0.336667  0.306667         0.710667    normal
# 53  0.363333  0.336667  0.306667         0.710667    normal
# 54  0.363333  0.336667  0.306667         0.710667    normal
# 55  0.363333  0.336667  0.306667         0.710667    normal
# 56  0.363333  0.336667  0.306667         0.710667    normal
# 57  0.363333  0.336667  0.306667         0.710667    normal
# 58  0.363333  0.336667  0.306667         0.710667    normal
# 59  0.363333  0.336667  0.306667         0.710667    normal
# 0        NaN       NaN       NaN              NaN    normal
# 1        NaN       NaN       NaN              NaN    normal
# 2        NaN       NaN       NaN              NaN    normal
# 3        NaN       NaN       NaN              NaN    normal
# 4        NaN       NaN       NaN              NaN    normal
# 5        NaN       NaN       NaN              NaN    normal
# 6        NaN       NaN       NaN              NaN    normal
# 7        NaN       NaN       NaN              NaN    normal
# 8        NaN       NaN       NaN              NaN    normal
# 9        NaN       NaN       NaN              NaN    normal
# 10       NaN       NaN       NaN              NaN    normal
# 11       NaN       NaN       NaN              NaN    normal
# 12       NaN       NaN       NaN              NaN    normal
# 13       NaN       NaN       NaN              NaN    normal
# 14       NaN       NaN       NaN              NaN    normal
# 15       NaN       NaN       NaN              NaN    normal
# 16       NaN       NaN       NaN              NaN    normal
# 17       NaN       NaN       NaN              NaN    normal
# 18       NaN       NaN       NaN              NaN    normal
# 19       NaN       NaN       NaN              NaN    normal

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-91effdcdc19e> in <module>
#       1 best_result = normal_imb_df[(normal_imb_df["R_e"] == 1) & (normal_imb_df["A@e"] == normal_imb_df["A@e"].max())]
# ----> 2 best_gini = best_result["gini"].values[0]
#       3 best_p = best_result["p value"].values[0]
#       4 best_run = best_result["Run"].values[0]
#       5
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# ### Untersuchung von Einfluss Parameter und Runs
#
# Zunächst untersuchen wir, was die besten Parameter und der beste Run ist und schauen uns das Ergebnis dafür an.

# %%
# Out:
# Text(0, 0.5, 'Accuracy at e (A@e)')

# %% [markdown]
# Nun schauen wir uns für die besten Parameter an, wie die Ergebnisse über die verschiedenen Runs sind. Dabei sieht man, dass auch für unterschiedliche Runs (also train/test splits) die besten Parameter unterschiedliche Ergebnisse erzielen können. SPH+CPI und SPH sind nun ungefähr gleich auf, aber trotzdem beide noch deutlich besser als RF+B.

# %%
methods_ordered = ["SPH+CPI", "SPH", "RF+B", "CPI"]

def write_values_lineplot(df, ax):
    palette = sns.color_palette()[0:5]
    color_per_label = {x:c for x,c in zip(methods_ordered, palette)}

    for item, color in zip(df.groupby('Method'),palette):
        #item[1] is a grouped data frame
        for x,y,method in item[1][['R_e','A@e','Method']].values:
            y = np.mean(y)
            y_position = round(y)
            x_position = x
            if method == "SPH+CPI":
                y_position = y_position +3
                x_position = x_position - 0.25
            else:
                y_position = y_position - 3
                if method == "SPH":
                    x_position = x + 0.25
                    if y_position == 33:
                        y_position = y_position + 7
                        print(y_position)
                if method == "CPI":
                    y_position = y_position - 3
                if method == "RF+B":
                    y_position = y_position - 1
                    
                
            ax.text(x_position,y_position,f'{y:.0f}%', color=color_per_label[method])

for imb in merged_df['imbalance'].unique():
    merged_df['Method'] = merged_df['Method'].apply(lambda x: 'SPH+CPI' if x == "Tailored Approach" else x)
    merged_df['Run'] = 1
    low_imb_df = merged_df[merged_df['imbalance'] == imb]
    best_result = low_imb_df[low_imb_df["Avg Acc SPH+CPI"] == low_imb_df["Avg Acc SPH+CPI"].max()]
    best_gini = best_result["gini"].values[0]
    best_p = best_result["p value"].values[0]
    best_run = best_result["Run"].values[0]
    #best_max_info_loss = best_result

    best_ta_methods = low_imb_df[((low_imb_df["gini"] ==best_gini) & (low_imb_df["Run"] == best_run) & (low_imb_df["p value"] == best_p))]
    best_other_methods = low_imb_df[(low_imb_df["Run"] == best_run) & (low_imb_df["gini"] == -1)]
    best_all_methods = pd.concat([best_ta_methods, best_other_methods])
    best_all_methods['A@e'] = best_all_methods['A@e']*100
    best_all_methods

    #sns.set_style("darkgrid")
    #best_run_df['A@e'] = best_run_df['A@e'].apply(lambda x: x*100)

    ax = sns.lineplot(x="R_e", y="A@e", data=best_all_methods, hue="Method", style="Method", markers=True, hue_order=methods_ordered)
    write_values_lineplot(best_all_methods, ax)

    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.set_xlabel(r'Recommendation lists $R_e$ with different lengths $e$')
    ax.set_ylim(0, 100)
    ax.set_xticks(range(1,11))
    ax.set_yticks(range(10, 110,10))
    ax.set_ylabel('Accuracy at e (A@e)')

    plt.legend(bbox_to_anchor=(1, -0.3), loc='lower right', ncol=5)
    plt.tight_layout()

    plt.savefig(f"accuracy_{imb}.pdf")
    plt.close()
# Out:
# 40.0

# %%
methods_ordered = ["SPH+CPI", "SPH", "RF+B", "CPI"]
imb = "very low"
def write_values_lineplot(df, ax):
    palette = sns.color_palette()[0:5]
    color_per_label = {x:c for x,c in zip(methods_ordered, palette)}

    for item, color in zip(df.groupby('Method'),palette):
        #item[1] is a grouped data frame
        for x,y,method in item[1][['R_e','A@e','Method']].values:
            y = np.mean(y)
            y_position = round(y)
            x_position = x
            if method == "SPH+CPI":
                y_position = y_position +3
                x_position = x_position - 0.25
            else:
                y_position = y_position - 3
                if method == "SPH":
                    x_position = x + 0.25
                    if y_position == 33:
                        y_position = y_position + 7
                        print(y_position)
                if method == "CPI":
                    y_position = y_position - 3
                if method == "RF+B":
                    y_position = y_position - 1
                    
                
            ax.text(x_position,y_position,f'{y:.0f}%', color=color_per_label[method])

merged_df['Method'] = merged_df['Method'].apply(lambda x: 'SPH+CPI' if x == "Tailored Approach" else x)
merged_df['Run'] = 1
low_imb_df = merged_df[merged_df['imbalance'] == imb]
best_result = low_imb_df[low_imb_df["Avg Acc SPH+CPI"] == low_imb_df["Avg Acc SPH+CPI"].max()]
best_gini = best_result["gini"].values[0]
best_p = best_result["p value"].values[0]
best_run = best_result["Run"].values[0]


best_ta_methods = low_imb_df[((low_imb_df["gini"] ==best_gini) & (low_imb_df["Run"] == best_run) & (low_imb_df["p value"] == best_p))]
best_other_methods = low_imb_df[(low_imb_df["Run"] == best_run) & (low_imb_df["gini"] == -1)]
best_all_methods = pd.concat([best_ta_methods, best_other_methods])
best_all_methods['A@e'] = best_all_methods['A@e']*100
best_all_methods

#sns.set_style("darkgrid")
#best_run_df['A@e'] = best_run_df['A@e'].apply(lambda x: x*100)

ax = sns.lineplot(x="R_e", y="A@e", data=best_all_methods, hue="Method", style="Method", markers=True, hue_order=methods_ordered)
write_values_lineplot(best_all_methods, ax)

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.set_xlabel(r'Recommendation lists $R_e$ with different lengths $e$')
ax.set_ylim(0, 100)
ax.set_xticks(range(1,11))
ax.set_yticks(range(10, 110,10))
ax.set_ylabel('Accuracy at e (A@e)')
plt.legend(loc='lower right')

plt.savefig(f"accuracy_{imb}.pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e4bbf0115333> in <module>
#      29             ax.text(x_position,y_position,f'{y:.0f}%', color=color_per_label[method])
#      30
# ---> 31 merged_df['Method'] = merged_df['Method'].apply(lambda x: 'SPH+CPI' if x == "Tailored Approach" else x)
#      32 merged_df['Run'] = 1
#      33 low_imb_df = merged_df[merged_df['imbalance'] == imb]
#
# NameError: name 'merged_df' is not defined

# %%
methods_ordered = ["SPH+CPI", "SPH", "RF+B", "CPI"]
def write_values_lineplot(df, ax):
    palette = sns.color_palette()[0:5]
    color_per_label = {x:c for x,c in zip(methods_ordered, palette)}

    for item, color in zip(df.groupby('Method'),palette):
        #item[1] is a grouped data frame
        for x,y,method in item[1][['R_e','A@e','Method']].values:
            y = np.mean(y)
            y_position = round(y)
            x_position = x
            if method == "SPH+CPI":
                y_position = y_position +3
                x_position = x_position - 0.25
            else:
                y_position = y_position - 3
                if method == "SPH":
                    x_position = x + 0.25
                    if y_position == 33:
                        y_position = y_position + 7
                        print(y_position)

                if method == "RF+B":
                    y_position = y_position - 1
                    
                
            ax.text(x_position,y_position,f'{y:.0f}%', color=color_per_label[method])
            
best_params = low_imb_df[((low_imb_df["gini"] == best_gini) & (low_imb_dfw["p value"] == best_p)) | (low_imb_df["gini"] ==-1)]
best_run_df = low_imb_df[low_imb_df["Run"] == best_run]
#sns.set_style("darkgrid")
#best_run_df['A@e'] = best_run_df['A@e'].apply(lambda x: x*100)

ax = sns.lineplot(x="R_e", y="A@e", data=best_all_methods, hue="Method", style="Method", markers=True, hue_order=methods_ordered)
write_values_lineplot(best_all_methods, ax)

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.set_xlabel(r'Recommendation lists $R_e$ with different lengths $e$')
ax.set_ylim(0, 100)
ax.set_xticks(range(1,11))
ax.set_yticks(range(10, 110,10))
ax.set_ylabel('Accuracy at e (A@e)')
plt.legend(loc='lower right')

plt.savefig("accuracy_normal.pdf")

# %% [markdown]
# Und jetzt noch wie die Ergebnisse sind, wenn wir den gleichen Run nehmen, aber unterschiedliche Parameter. D.h. wie sich die Parameter auswirken können auf SPH+CPI. Hier sieht man nun, dass SPH+CPI nicht mehr besser ist als SPH (im median) und somit haben die Parameter einen starken Einfluss auf SPH+CPI, was wiederun heißt, dass die Parameteroptimierung schon wichtig ist.

# %%
sns.lineplot(x="R_e", y="A@e", data=best_run_df, hue="Method")

# %% [markdown]
# ## Beste Parameter von normal im Vergleich zu anderen Imbalance Degrees
# Hier mergen wir alle Ergebnisse für very_low, low, normal, high und very_high und schauen uns die Ergebnisse an, wenn wir die besten Parameter für normal nehmen.

# %%
low_imb_df = pd.read_csv('../imbalance_degree/low/result_split/gini_accuracy_all_runs.csv')
very_low_imb_df = pd.read_csv('../imbalance_degree/very_low/result_split/gini_accuracy_all_runs.csv')
high_imb_df = pd.read_csv('../imbalance_degree/high/result_split/gini_accuracy_all_runs.csv')
very_high_imb_df = pd.read_csv('../imbalance_degree/very_high/result_split/gini_accuracy_all_runs.csv')


low_imb_df["imbalance"] = "low"
very_low_imb_df["imbalance"] = "very low"
normal_imb_df["imbalance"] = "normal"
high_imb_df["imbalance"] = "high"
very_high_imb_df["imbalance"] = "very high"
normal_imb_df
# Out:
#      R_e       A@e   Method  gini  p value  Run  SPH Executed  info loss  \
# 0      1  0.363333      SPH  -1.0     -1.0    1          10.0       0.25
# 1      2  0.560000      SPH  -1.0     -1.0    1          10.0       0.25
# 2      3  0.650000      SPH  -1.0     -1.0    1          10.0       0.25
# 3      4  0.726667      SPH  -1.0     -1.0    1          10.0       0.25
# 4      5  0.786667      SPH  -1.0     -1.0    1          10.0       0.25
# ..   ...       ...      ...   ...      ...  ...           ...        ...
# 195    6  0.803333  SPH+CPI   0.4      0.9    1          10.0       0.25
# 196    7  0.826667  SPH+CPI   0.4      0.9    1          10.0       0.25
# 197    8  0.836667  SPH+CPI   0.4      0.9    1          10.0       0.25
# 198    9  0.853333  SPH+CPI   0.4      0.9    1          10.0       0.25
# 199   10  0.856667  SPH+CPI   0.4      0.9    1          10.0       0.25
#
#       SPH A@1  RF+B A@1   CPI A@1  Avg Acc SPH+CPI imbalance
# 0         NaN       NaN       NaN              NaN    normal
# 1         NaN       NaN       NaN              NaN    normal
# 2         NaN       NaN       NaN              NaN    normal
# 3         NaN       NaN       NaN              NaN    normal
# 4         NaN       NaN       NaN              NaN    normal
# ..        ...       ...       ...              ...       ...
# 195  0.363333  0.336667  0.243333            0.728    normal
# 196  0.363333  0.336667  0.243333            0.728    normal
# 197  0.363333  0.336667  0.243333            0.728    normal
# 198  0.363333  0.336667  0.243333            0.728    normal
# 199  0.363333  0.336667  0.243333            0.728    normal
#
# [200 rows x 13 columns]

# %% [markdown]
# Nun werden alle gemerged und nach den besten Parametern von normal gefiltert.

# %%
merged_df = pd.concat([ very_high_imb_df, high_imb_df, normal_imb_df, low_imb_df, very_low_imb_df])

merged_df["Method"] = merged_df["Method"].apply(lambda x: "SPH+CPI" if x=="Tailored Approach" else x)

best_merged_df = merged_df[(((merged_df["gini"] == best_gini) & (merged_df["p value"] == best_p)) | (merged_df["gini"] ==-1) & (merged_df["p value"] == -1))]
print(best_merged_df["imbalance"].unique())
best_merged_df["Run"] = 1
best_merged_df.head(20)
best_merged_df["A@e"] = best_merged_df["A@e"] * 100
# Out:
# ['very high' 'high' 'normal' 'low' 'very low']
# <ipython-input-8-5cb21bd3440a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_merged_df["Run"] = 1
# <ipython-input-8-5cb21bd3440a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_merged_df["A@e"] = best_merged_df["A@e"] * 100

# %% [markdown]
# Ergbnis bzgl. Accuracy wird nun visualisiert.
# Man sieht, dass mit steigern imabalance auch die Accuracy (zumindest A@1) steigt und genau andersrum, dass mit sinkender imbalance die Accuracy sinkt.

# %%
#ax = sns.lineplot(x="R_e", y="A@e", hue="imbalance", data=best_merged_df,  markers=True, palette=palette)
def line_plot_write_imb_values(df):
    print(df["imbalance"].unique())
    df["imbalance"] = pd.Categorical(df["imbalance"], 
                      categories=["very high","high","normal","low","very low"],
                      ordered=True)
    palette = sns.color_palette()[0:len(df["imbalance"].unique())]
    print(len(palette))
    print(df["imbalance"].unique())
    df = df.sort_values("imbalance")
    color_per_label = {x:c for x,c in zip(df["imbalance"].unique(), palette)}
    ax = sns.lineplot(x="R_e", y="A@e", hue="imbalance", style="imbalance", data=df, markers=True, palette=palette)

    for item, color in zip(df.groupby('imbalance'),palette):
        #item[1] is a grouped data frame
        for x,y,imb in item[1][['R_e','A@e','imbalance']].values:
            x_position = x
            y_position = y
            if imb == "high":
                y_position = y_position - 5
            elif imb == "very high":
                y_position = y_position + 2
            elif imb == "normal":
                y_position = y_position + 1
                x_position = x_position - 0.4
            elif imb == "low" or imb == "very low":
                y_position = y_position - 5
            ax.text(x_position,y_position,f'{y:.0f}', color=color_per_label[imb])
    return ax

print(best_merged_df.head())
best_merged_df["Method"].unique()
ax = line_plot_write_imb_values(best_merged_df[best_merged_df["Method"]=="SPH+CPI"])
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.set_xlabel(r'Recommendation lists $R_e$ with different lengths $e$')
ax.set_ylim(0, 100)
ax.set_xticks(range(1,11))
ax.set_yticks(range(10, 110,10))
ax.set_ylabel('Accuracy at e (A@e)')
plt.legend(loc='lower right')
plt.savefig("accuracy_imb_degrees_SPH+CPI.pdf")
# Out:
#    R_e        A@e Method  gini  p value  Run  SPH Executed  info loss  \
# 0    1  56.333333    SPH  -1.0     -1.0    1          18.0       0.25
# 1    2  62.333333    SPH  -1.0     -1.0    1          18.0       0.25
# 2    3  65.666667    SPH  -1.0     -1.0    1          18.0       0.25
# 3    4  70.000000    SPH  -1.0     -1.0    1          18.0       0.25
# 4    5  73.000000    SPH  -1.0     -1.0    1          18.0       0.25
#
#    SPH A@1  RF+B A@1  CPI A@1  Avg Acc SPH+CPI  imbalance
# 0      NaN       NaN      NaN              NaN  very high
# 1      NaN       NaN      NaN              NaN  very high
# 2      NaN       NaN      NaN              NaN  very high
# 3      NaN       NaN      NaN              NaN  very high
# 4      NaN       NaN      NaN              NaN  very high
# ['very high' 'high' 'normal' 'low' 'very low']
# 5
# ['very high', 'high', 'normal', 'low', 'very low']
# Categories (5, object): ['very high' < 'high' < 'normal' < 'low' < 'very low']
# <ipython-input-7-2b6f59fc9ad1>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["imbalance"] = pd.Categorical(df["imbalance"],

# %%
#ax = sns.lineplot(x="R_e", y="A@e", hue="imbalance", data=best_merged_df,  markers=True, palette=palette)
def line_plot_write_imb_values(df):
    print(df["imbalance"].unique())
    df["imbalance"] = pd.Categorical(df["imbalance"], 
                      categories=["very high","high","normal","low","very low"],
                      ordered=True)
    palette = sns.color_palette()[0:len(df["imbalance"].unique())]
    print(len(palette))
    print(df["imbalance"].unique())
    df = df.sort_values("imbalance")
    color_per_label = {x:c for x,c in zip(df["imbalance"].unique(), palette)}
    ax = sns.lineplot(x="R_e", y="A@e", hue="imbalance", style="imbalance", data=df, markers=True, palette=palette)

    for item, color in zip(df.groupby('imbalance'),palette):
        #item[1] is a grouped data frame
        for x,y,imb in item[1][['R_e','A@e','imbalance']].values:
            x_position = x
            y_position = y
            if imb == "high":
                if x == 1:
                    y_position = y_position + 5
                else:
                    y_position = y_position - 5
            elif imb == "very high":
                y_position = y_position + 2
            elif imb == "normal":
                y_position = y_position + 1
                x_position = x_position - 0.4
            elif imb == "low" or imb == "very low":
                y_position = y_position - 5
            ax.text(x_position,y_position,f'{y:.0f}', color=color_per_label[imb])
    return ax

print(best_merged_df.head())
best_merged_df["Method"].unique()
ax = line_plot_write_imb_values(best_merged_df[best_merged_df["Method"]=="SPH+CPI"])
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.set_xlabel(r'Recommendation lists $R_e$ with different lengths $e$')
ax.set_ylim(0, 100)
ax.set_xticks(range(1,11))
ax.set_yticks(range(10, 110,10))
ax.set_ylabel('Accuracy at e (A@e)')
plt.legend(loc='lower right')
plt.savefig("accuracy_imb_degrees_SPH_CPI.pdf")
# Out:
#    R_e        A@e Method  gini  p value  Run  SPH Executed  info loss  \
# 0    1  56.333333    SPH  -1.0     -1.0    1          18.0       0.25
# 1    2  62.333333    SPH  -1.0     -1.0    1          18.0       0.25
# 2    3  65.666667    SPH  -1.0     -1.0    1          18.0       0.25
# 3    4  70.000000    SPH  -1.0     -1.0    1          18.0       0.25
# 4    5  73.000000    SPH  -1.0     -1.0    1          18.0       0.25
#
#    SPH A@1  RF+B A@1  CPI A@1  Avg Acc SPH+CPI  imbalance
# 0      NaN       NaN      NaN              NaN  very high
# 1      NaN       NaN      NaN              NaN  very high
# 2      NaN       NaN      NaN              NaN  very high
# 3      NaN       NaN      NaN              NaN  very high
# 4      NaN       NaN      NaN              NaN  very high
# ['very high' 'high' 'normal' 'low' 'very low']
# 5
# ['very high', 'high', 'normal', 'low', 'very low']
# Categories (5, object): ['very high' < 'high' < 'normal' < 'low' < 'very low']
# <ipython-input-50-1924ab8bb84a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["imbalance"] = pd.Categorical(df["imbalance"],

# %%
best_merged_df_sph = merged_df[(merged_df["gini"] == -1) & (merged_df["p value"] == -1) & (merged_df["Run"] == best_run) & (merged_df["Method"]=="SPH")]
best_merged_df_sph
# Out:
#       R_e       A@e Method  gini  p value  Run  SPH Executed  info loss  \
# 1000    1  0.276667    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1001    2  0.366667    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1002    3  0.470000    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1003    4  0.523333    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1004    5  0.553333    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1005    6  0.590000    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1006    7  0.626667    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1007    8  0.663333    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1008    9  0.690000    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1009   10  0.703333    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1000    1  0.316667    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1001    2  0.493333    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1002    3  0.616667    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1003    4  0.706667    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1004    5  0.743333    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1005    6  0.773333    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1006    7  0.806667    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1007    8  0.820000    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1008    9  0.826667    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1009   10  0.836667    SPH  -1.0     -1.0  3.0          10.0       0.25
# 1000    1  0.176667    SPH  -1.0     -1.0  3.0           6.0       0.25
# 1001    2  0.270000    SPH  -1.0     -1.0  3.0           6.0       0.25
# 1002    3  0.366667    SPH  -1.0     -1.0  3.0           6.0       0.25
# 1003    4  0.420000    SPH  -1.0     -1.0  3.0           6.0       0.25
# 1004    5  0.476667    SPH  -1.0     -1.0  3.0           6.0       0.25
# 1005    6  0.506667    SPH  -1.0     -1.0  3.0           6.0       0.25
# 1006    7  0.546667    SPH  -1.0     -1.0  3.0           6.0       0.25
# 1007    8  0.580000    SPH  -1.0     -1.0  3.0           6.0       0.25
# 1008    9  0.606667    SPH  -1.0     -1.0  3.0           6.0       0.25
# 1009   10  0.633333    SPH  -1.0     -1.0  3.0           6.0       0.25
# 1000    1  0.460000    SPH  -1.0     -1.0  3.0          11.0       0.25
# 1001    2  0.576667    SPH  -1.0     -1.0  3.0          11.0       0.25
# 1002    3  0.646667    SPH  -1.0     -1.0  3.0          11.0       0.25
# 1003    4  0.693333    SPH  -1.0     -1.0  3.0          11.0       0.25
# 1004    5  0.736667    SPH  -1.0     -1.0  3.0          11.0       0.25
# 1005    6  0.766667    SPH  -1.0     -1.0  3.0          11.0       0.25
# 1006    7  0.780000    SPH  -1.0     -1.0  3.0          11.0       0.25
# 1007    8  0.790000    SPH  -1.0     -1.0  3.0          11.0       0.25
# 1008    9  0.800000    SPH  -1.0     -1.0  3.0          11.0       0.25
# 1009   10  0.820000    SPH  -1.0     -1.0  3.0          11.0       0.25
# 1000    1  0.550000    SPH  -1.0     -1.0  3.0          13.0       0.25
# 1001    2  0.620000    SPH  -1.0     -1.0  3.0          13.0       0.25
# 1002    3  0.653333    SPH  -1.0     -1.0  3.0          13.0       0.25
# 1003    4  0.683333    SPH  -1.0     -1.0  3.0          13.0       0.25
# 1004    5  0.720000    SPH  -1.0     -1.0  3.0          13.0       0.25
# 1005    6  0.760000    SPH  -1.0     -1.0  3.0          13.0       0.25
# 1006    7  0.770000    SPH  -1.0     -1.0  3.0          13.0       0.25
# 1007    8  0.780000    SPH  -1.0     -1.0  3.0          13.0       0.25
# 1008    9  0.793333    SPH  -1.0     -1.0  3.0          13.0       0.25
# 1009   10  0.810000    SPH  -1.0     -1.0  3.0          13.0       0.25
#
#       SPH A@1  RF+B A@1  CPI A@1  Avg Acc SPH+CPI  imbalance
# 1000      NaN       NaN      NaN              NaN        low
# 1001      NaN       NaN      NaN              NaN        low
# 1002      NaN       NaN      NaN              NaN        low
# 1003      NaN       NaN      NaN              NaN        low
# 1004      NaN       NaN      NaN              NaN        low
# 1005      NaN       NaN      NaN              NaN        low
# 1006      NaN       NaN      NaN              NaN        low
# 1007      NaN       NaN      NaN              NaN        low
# 1008      NaN       NaN      NaN              NaN        low
# 1009      NaN       NaN      NaN              NaN        low
# 1000      NaN       NaN      NaN              NaN     normal
# 1001      NaN       NaN      NaN              NaN     normal
# 1002      NaN       NaN      NaN              NaN     normal
# 1003      NaN       NaN      NaN              NaN     normal
# 1004      NaN       NaN      NaN              NaN     normal
# 1005      NaN       NaN      NaN              NaN     normal
# 1006      NaN       NaN      NaN              NaN     normal
# 1007      NaN       NaN      NaN              NaN     normal
# 1008      NaN       NaN      NaN              NaN     normal
# 1009      NaN       NaN      NaN              NaN     normal
# 1000      NaN       NaN      NaN              NaN   very low
# 1001      NaN       NaN      NaN              NaN   very low
# 1002      NaN       NaN      NaN              NaN   very low
# 1003      NaN       NaN      NaN              NaN   very low
# 1004      NaN       NaN      NaN              NaN   very low
# 1005      NaN       NaN      NaN              NaN   very low
# 1006      NaN       NaN      NaN              NaN   very low
# 1007      NaN       NaN      NaN              NaN   very low
# 1008      NaN       NaN      NaN              NaN   very low
# 1009      NaN       NaN      NaN              NaN   very low
# 1000      NaN       NaN      NaN              NaN       high
# 1001      NaN       NaN      NaN              NaN       high
# 1002      NaN       NaN      NaN              NaN       high
# 1003      NaN       NaN      NaN              NaN       high
# 1004      NaN       NaN      NaN              NaN       high
# 1005      NaN       NaN      NaN              NaN       high
# 1006      NaN       NaN      NaN              NaN       high
# 1007      NaN       NaN      NaN              NaN       high
# 1008      NaN       NaN      NaN              NaN       high
# 1009      NaN       NaN      NaN              NaN       high
# 1000      NaN       NaN      NaN              NaN  very high
# 1001      NaN       NaN      NaN              NaN  very high
# 1002      NaN       NaN      NaN              NaN  very high
# 1003      NaN       NaN      NaN              NaN  very high
# 1004      NaN       NaN      NaN              NaN  very high
# 1005      NaN       NaN      NaN              NaN  very high
# 1006      NaN       NaN      NaN              NaN  very high
# 1007      NaN       NaN      NaN              NaN  very high
# 1008      NaN       NaN      NaN              NaN  very high
# 1009      NaN       NaN      NaN              NaN  very high

# %% [markdown]
# Accuracy für verschiedene imbalance degrees für SPH. Hier sehen wir, dass die Accuracy sehr ähnlich ist zu SPH+CPI, aber auch daran liegt, dass wir die PArameter von CPI nicht optimieren.

# %%
line_plot_write_imb_values(best_merged_df_sph)
# Out:
# ['low' 'normal' 'very low' 'high' 'very high']
# 5
# ['low', 'normal', 'very low', 'high', 'very high']
# Categories (5, object): ['normal' < 'low' < 'very low' < 'high' < 'very high']
# <ipython-input-130-f82b6e409d45>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["imbalance"] = pd.Categorical(df["imbalance"],

# %%
best_merged_df_sph_Rf = merged_df[(merged_df["gini"] == -1) & (merged_df["p value"] == -1) & (merged_df["Run"] == best_run) & (merged_df["Method"]=="RF+B")]
best_merged_df_sph_Rf
line_plot_write_imb_values(best_merged_df_sph_Rf)
# Out:
# ['low' 'normal' 'very low' 'high' 'very high']
# 5
# ['low', 'normal', 'very low', 'high', 'very high']
# Categories (5, object): ['normal' < 'low' < 'very low' < 'high' < 'very high']
# <ipython-input-82-f82b6e409d45>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["imbalance"] = pd.Categorical(df["imbalance"],

# %%
def line_plot_write_imb_values(df):
    print(df["imbalance"].unique())
    df["imbalance"] = pd.Categorical(df["imbalance"], 
                      categories=["normal","low","very low","high", "very high"],
                      ordered=True)
    palette = sns.color_palette()[0:len(df["imbalance"].unique())]
    print(len(palette))
    print(df["imbalance"].unique())
    df = df.sort_values("imbalance")
    color_per_label = {x:c for x,c in zip(df["imbalance"].unique(), palette)}
    ax = sns.lineplot(x="R_e", y="A@e", hue="imbalance", data=df, markers=True, palette=palette)

    for item, color in zip(df.groupby('imbalance'),palette):
        #item[1] is a grouped data frame
        for x,y,imb in item[1][['R_e','A@e','imbalance']].values:
            ax.text(x,y,f'{y:.2f}', color=color_per_label[imb])

# %% [markdown]
# ## Accuracy für jeden imbalance degree optimiert
#
# Jetzt schauen wir uns die Accuracy für die verschiedenen imbalance degrees an, wenn wir jeweils die Parameter für jeden einzeln optimieren

# %%
best_result_each_degree = pd.DataFrame()
low_imb_df.head()
frames = [very_low_imb_df, low_imb_df, normal_imb_df, high_imb_df, very_high_imb_df]
for frame in frames:    
    best_result = frame[frame["Avg Acc SPH+CPI"] == frame["Avg Acc SPH+CPI"].max()]
    #best_result = best_result[best_result['A@e'] == best_result['A@e']]
    best_gini = best_result["gini"].values[0]
    best_p = best_result["p value"].values[0]
    best_run = 1
    print(f"best run for imb degree {frame['imbalance'].values[0]} is: {best_run}")
    # best result for SPH+CPI
    best_ta_methods = frame[((frame["gini"] ==best_gini) & (frame["Run"] == best_run) & (frame["p value"] == best_p))]
    print(best_ta_methods)
    best_result_each_degree = pd.concat([best_result_each_degree, best_ta_methods])
    
    
best_result_each_degree
best_result_each_degree['A@e'] = best_result_each_degree['A@e'] * 100
best_result_each_degree['Method'] = best_result_each_degree['Method'].apply(lambda x: 'SPH+CPI' if x == "Tailored Approach" else x)
best_result_each_degree[(best_result_each_degree['R_e'] ==1) & (best_result_each_degree['imbalance'] == 'low')]
# Out:
# best run for imb degree very low is: 1
#     R_e       A@e             Method  gini  p value  Run  SPH Executed  \
# 30    1  0.133333  Tailored Approach   0.3      0.7  1.0          11.0
# 31    2  0.213333  Tailored Approach   0.3      0.7  1.0          11.0
# 32    3  0.273333  Tailored Approach   0.3      0.7  1.0          11.0
# 33    4  0.313333  Tailored Approach   0.3      0.7  1.0          11.0
# 34    5  0.380000  Tailored Approach   0.3      0.7  1.0          11.0
# 35    6  0.443333  Tailored Approach   0.3      0.7  1.0          11.0
# 36    7  0.496667  Tailored Approach   0.3      0.7  1.0          11.0
# 37    8  0.523333  Tailored Approach   0.3      0.7  1.0          11.0
# 38    9  0.553333  Tailored Approach   0.3      0.7  1.0          11.0
# 39   10  0.573333  Tailored Approach   0.3      0.7  1.0          11.0
#
#     info loss   SPH A@1  RF+B A@1  CPI A@1  Avg Acc SPH+CPI imbalance
# 30       0.25  0.133333  0.076667     0.05         0.390333  very low
# 31       0.25  0.133333  0.076667     0.05         0.390333  very low
# 32       0.25  0.133333  0.076667     0.05         0.390333  very low
# 33       0.25  0.133333  0.076667     0.05         0.390333  very low
# 34       0.25  0.133333  0.076667     0.05         0.390333  very low
# 35       0.25  0.133333  0.076667     0.05         0.390333  very low
# 36       0.25  0.133333  0.076667     0.05         0.390333  very low
# 37       0.25  0.133333  0.076667     0.05         0.390333  very low
# 38       0.25  0.133333  0.076667     0.05         0.390333  very low
# 39       0.25  0.133333  0.076667     0.05         0.390333  very low
# best run for imb degree low is: 1
#      R_e       A@e             Method  gini  p value  Run  SPH Executed  \
# 110    1  0.243333  Tailored Approach  0.35      0.8  1.0           9.0
# 111    2  0.370000  Tailored Approach  0.35      0.8  1.0           9.0
# 112    3  0.466667  Tailored Approach  0.35      0.8  1.0           9.0
# 113    4  0.510000  Tailored Approach  0.35      0.8  1.0           9.0
# 114    5  0.553333  Tailored Approach  0.35      0.8  1.0           9.0
# 115    6  0.590000  Tailored Approach  0.35      0.8  1.0           9.0
# 116    7  0.636667  Tailored Approach  0.35      0.8  1.0           9.0
# 117    8  0.656667  Tailored Approach  0.35      0.8  1.0           9.0
# 118    9  0.680000  Tailored Approach  0.35      0.8  1.0           9.0
# 119   10  0.696667  Tailored Approach  0.35      0.8  1.0           9.0
#
#      info loss   SPH A@1  RF+B A@1   CPI A@1  Avg Acc SPH+CPI imbalance
# 110       0.25  0.243333      0.21  0.146667         0.540333       low
# 111       0.25  0.243333      0.21  0.146667         0.540333       low
# 112       0.25  0.243333      0.21  0.146667         0.540333       low
# 113       0.25  0.243333      0.21  0.146667         0.540333       low
# 114       0.25  0.243333      0.21  0.146667         0.540333       low
# 115       0.25  0.243333      0.21  0.146667         0.540333       low
# 116       0.25  0.243333      0.21  0.146667         0.540333       low
# 117       0.25  0.243333      0.21  0.146667         0.540333       low
# 118       0.25  0.243333      0.21  0.146667         0.540333       low
# 119       0.25  0.243333      0.21  0.146667         0.540333       low
# best run for imb degree normal is: 1
#      R_e       A@e   Method  gini  p value  Run  SPH Executed  info loss  \
# 180    1  0.243333      CPI   0.4      0.9    1           NaN        NaN
# 181    2  0.343333      CPI   0.4      0.9    1           NaN        NaN
# 182    3  0.446667      CPI   0.4      0.9    1           NaN        NaN
# 183    4  0.513333      CPI   0.4      0.9    1           NaN        NaN
# 184    5  0.560000      CPI   0.4      0.9    1           NaN        NaN
# 185    6  0.583333      CPI   0.4      0.9    1           NaN        NaN
# 186    7  0.636667      CPI   0.4      0.9    1           NaN        NaN
# 187    8  0.683333      CPI   0.4      0.9    1           NaN        NaN
# 188    9  0.700000      CPI   0.4      0.9    1           NaN        NaN
# 189   10  0.736667      CPI   0.4      0.9    1           NaN        NaN
# 190    1  0.400000  SPH+CPI   0.4      0.9    1          10.0       0.25
# 191    2  0.573333  SPH+CPI   0.4      0.9    1          10.0       0.25
# 192    3  0.633333  SPH+CPI   0.4      0.9    1          10.0       0.25
# 193    4  0.716667  SPH+CPI   0.4      0.9    1          10.0       0.25
# 194    5  0.780000  SPH+CPI   0.4      0.9    1          10.0       0.25
# 195    6  0.803333  SPH+CPI   0.4      0.9    1          10.0       0.25
# 196    7  0.826667  SPH+CPI   0.4      0.9    1          10.0       0.25
# 197    8  0.836667  SPH+CPI   0.4      0.9    1          10.0       0.25
# 198    9  0.853333  SPH+CPI   0.4      0.9    1          10.0       0.25
# 199   10  0.856667  SPH+CPI   0.4      0.9    1          10.0       0.25
#
#       SPH A@1  RF+B A@1   CPI A@1  Avg Acc SPH+CPI imbalance
# 180       NaN       NaN       NaN              NaN    normal
# 181       NaN       NaN       NaN              NaN    normal
# 182       NaN       NaN       NaN              NaN    normal
# 183       NaN       NaN       NaN              NaN    normal
# 184       NaN       NaN       NaN              NaN    normal
# 185       NaN       NaN       NaN              NaN    normal
# 186       NaN       NaN       NaN              NaN    normal
# 187       NaN       NaN       NaN              NaN    normal
# 188       NaN       NaN       NaN              NaN    normal
# 189       NaN       NaN       NaN              NaN    normal
# 190  0.363333  0.336667  0.243333            0.728    normal
# 191  0.363333  0.336667  0.243333            0.728    normal
# 192  0.363333  0.336667  0.243333            0.728    normal
# 193  0.363333  0.336667  0.243333            0.728    normal
# 194  0.363333  0.336667  0.243333            0.728    normal
# 195  0.363333  0.336667  0.243333            0.728    normal
# 196  0.363333  0.336667  0.243333            0.728    normal
# 197  0.363333  0.336667  0.243333            0.728    normal
# 198  0.363333  0.336667  0.243333            0.728    normal
# 199  0.363333  0.336667  0.243333            0.728    normal
# best run for imb degree high is: 1
#      R_e       A@e             Method  gini  p value  Run  SPH Executed  \
# 110    1  0.440000  Tailored Approach  0.35      0.8  1.0          14.0
# 111    2  0.526667  Tailored Approach  0.35      0.8  1.0          14.0
# 112    3  0.626667  Tailored Approach  0.35      0.8  1.0          14.0
# 113    4  0.676667  Tailored Approach  0.35      0.8  1.0          14.0
# 114    5  0.720000  Tailored Approach  0.35      0.8  1.0          14.0
# 115    6  0.730000  Tailored Approach  0.35      0.8  1.0          14.0
# 116    7  0.736667  Tailored Approach  0.35      0.8  1.0          14.0
# 117    8  0.753333  Tailored Approach  0.35      0.8  1.0          14.0
# 118    9  0.773333  Tailored Approach  0.35      0.8  1.0          14.0
# 119   10  0.790000  Tailored Approach  0.35      0.8  1.0          14.0
#
#      info loss  SPH A@1  RF+B A@1   CPI A@1  Avg Acc SPH+CPI imbalance
# 110       0.25     0.42      0.38  0.383333         0.677333      high
# 111       0.25     0.42      0.38  0.383333         0.677333      high
# 112       0.25     0.42      0.38  0.383333         0.677333      high
# 113       0.25     0.42      0.38  0.383333         0.677333      high
# 114       0.25     0.42      0.38  0.383333         0.677333      high
# 115       0.25     0.42      0.38  0.383333         0.677333      high
# 116       0.25     0.42      0.38  0.383333         0.677333      high
# 117       0.25     0.42      0.38  0.383333         0.677333      high
# 118       0.25     0.42      0.38  0.383333         0.677333      high
# 119       0.25     0.42      0.38  0.383333         0.677333      high
# best run for imb degree very high is: 1
#      R_e       A@e             Method  gini  p value  Run  SPH Executed  \
# 170    1  0.560000  Tailored Approach   0.4      0.8  1.0          18.0
# 171    2  0.633333  Tailored Approach   0.4      0.8  1.0          18.0
# 172    3  0.656667  Tailored Approach   0.4      0.8  1.0          18.0
# 173    4  0.706667  Tailored Approach   0.4      0.8  1.0          18.0
# 174    5  0.733333  Tailored Approach   0.4      0.8  1.0          18.0
# 175    6  0.763333  Tailored Approach   0.4      0.8  1.0          18.0
# 176    7  0.783333  Tailored Approach   0.4      0.8  1.0          18.0
# 177    8  0.793333  Tailored Approach   0.4      0.8  1.0          18.0
# 178    9  0.803333  Tailored Approach   0.4      0.8  1.0          18.0
# 179   10  0.806667  Tailored Approach   0.4      0.8  1.0          18.0
#
#      info loss   SPH A@1  RF+B A@1   CPI A@1  Avg Acc SPH+CPI  imbalance
# 170       0.25  0.563333  0.533333  0.503333            0.724  very high
# 171       0.25  0.563333  0.533333  0.503333            0.724  very high
# 172       0.25  0.563333  0.533333  0.503333            0.724  very high
# 173       0.25  0.563333  0.533333  0.503333            0.724  very high
# 174       0.25  0.563333  0.533333  0.503333            0.724  very high
# 175       0.25  0.563333  0.533333  0.503333            0.724  very high
# 176       0.25  0.563333  0.533333  0.503333            0.724  very high
# 177       0.25  0.563333  0.533333  0.503333            0.724  very high
# 178       0.25  0.563333  0.533333  0.503333            0.724  very high
# 179       0.25  0.563333  0.533333  0.503333            0.724  very high
#      R_e        A@e   Method  gini  p value  Run  SPH Executed  info loss  \
# 110    1  24.333333  SPH+CPI  0.35      0.8  1.0           9.0       0.25
#
#       SPH A@1  RF+B A@1   CPI A@1  Avg Acc SPH+CPI imbalance
# 110  0.243333      0.21  0.146667         0.540333       low

# %%
low_imb_df.head()
# Out:
#    R_e       A@e Method  gini  p value  Run  SPH Executed  info loss  SPH A@1  \
# 0    1  0.243333    SPH  -1.0     -1.0  1.0           9.0       0.25      NaN
# 1    2  0.380000    SPH  -1.0     -1.0  1.0           9.0       0.25      NaN
# 2    3  0.466667    SPH  -1.0     -1.0  1.0           9.0       0.25      NaN
# 3    4  0.506667    SPH  -1.0     -1.0  1.0           9.0       0.25      NaN
# 4    5  0.550000    SPH  -1.0     -1.0  1.0           9.0       0.25      NaN
#
#    RF+B A@1  CPI A@1  Avg Acc SPH+CPI imbalance
# 0       NaN      NaN              NaN       low
# 1       NaN      NaN              NaN       low
# 2       NaN      NaN              NaN       low
# 3       NaN      NaN              NaN       low
# 4       NaN      NaN              NaN       low

# %%
best_result_each_degree[['A@e', 'gini', 'p value', 'Avg Acc SPH+CPI', 'imbalance']][(best_result_each_degree['R_e'] == 1) & (best_result_each_degree['Avg Acc SPH+CPI'] != np.NaN)]
# Out:
#            A@e  gini  p value  Avg Acc SPH+CPI  imbalance
# 30   13.333333  0.30      0.7         0.390333   very low
# 110  24.333333  0.35      0.8         0.540333        low
# 180  24.333333  0.40      0.9              NaN     normal
# 190  40.000000  0.40      0.9         0.728000     normal
# 110  44.000000  0.35      0.8         0.677333       high
# 170  56.000000  0.40      0.8         0.724000  very high

# %%
ax = line_plot_write_imb_values(best_result_each_degree[best_result_each_degree['Method'] == 'SPH+CPI'])
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.set_xlabel(r'Recommendation lists $R_e$ with different lengths $e$')
ax.set_ylim(0, 100)
ax.set_xticks(range(1,11))
ax.set_yticks(range(10, 110,10))
ax.set_ylabel('Accuracy at e (A@e)')
plt.legend(loc='lower right')
plt.savefig("accuracy_imb_degrees_SPH_CPI_optimized.pdf")
# Out:
# ['very low' 'low' 'normal' 'high' 'very high']
# 5
# ['very low', 'low', 'normal', 'high', 'very high']
# Categories (5, object): ['very high' < 'high' < 'normal' < 'low' < 'very low']
# <ipython-input-68-32b9ec7499bd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["imbalance"] = pd.Categorical(df["imbalance"],

# %%
best_result = normal_imb_df[normal_imb_df["Avg Acc SPH+CPI"] == normal_imb_df["Avg Acc SPH+CPI"].max()]
#best_gini = best_result["gini"].values[0]
best_gini = 0.3
#best_p = best_result["p value"].values[0]
best_p = 0.8
best_run = best_result["Run"].values[0]


best_ta_methods = merged_df[((merged_df["gini"] ==best_gini) & (merged_df["Run"] == best_run) & (merged_df["p value"] == best_p)) & (merged_df['Method']=="SPH+CPI") & ( merged_df['R_e']==1)]
#best_other_methods = merged_df[(merged_df["Run"] == best_run) & (merged_df["gini"] == -1)]
#best_all_methods = pd.concat([best_ta_methods, best_other_methods])
#best_all_methods['A@e'] = best_all_methods['A@e']*100
best_ta_methods[['A@e', 'gini', 'p value', 'Avg Acc SPH+CPI', 'imbalance']]
# Out:
#          A@e  gini  p value  Avg Acc SPH+CPI  imbalance
# 50  0.560000   0.3      0.8         0.716000  very high
# 50  0.440000   0.3      0.8         0.673000       high
# 50  0.333333   0.3      0.8         0.710667     normal
# 50  0.246667   0.3      0.8         0.538667        low
# 50  0.133333   0.3      0.8         0.390333   very low

# %%
best_result_each_degree['parameter'] = 'optimized'
best_ta_methods = merged_df[((merged_df["gini"] ==best_gini) & (merged_df["Run"] == best_run) & (merged_df["p value"] == best_p)) & (merged_df['Method']=="SPH+CPI")]
best_ta_methods['parameter'] = 'normal'
best_ta_methods['A@e'] = best_ta_methods['A@e'] * 100
optimized_df = pd.concat([best_result_each_degree, best_ta_methods])
ax = sns.lineplot(data=optimized_df[(optimized_df['Method']=="SPH+CPI") &(optimized_df['imbalance'] == 'low')], x="R_e", y='A@e', hue='parameter', style='parameter', markers=True)

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.set_xlabel(r'Recommendation lists $R_e$ with different lengths $e$')
ax.set_ylim(0, 100)
ax.set_xticks(range(1,11))
ax.set_yticks(range(10, 110,10))
ax.set_ylabel('Accuracy at e (A@e)')
plt.legend(loc='lower right')

plt.savefig(f"accuracy_optimized_low.pdf")
# Out:
# <ipython-input-72-19739132318b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_ta_methods['parameter'] = 'normal'
# <ipython-input-72-19739132318b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_ta_methods['A@e'] = best_ta_methods['A@e'] * 100
