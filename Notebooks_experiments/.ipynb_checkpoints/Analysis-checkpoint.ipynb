# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Vergleich für unterschiedliche imbalance degrees
#
# Wir haben insgesamt 5 verschiede imbalance degrees, die wir im FOlgenden betrachten: very_low, low, normal, high und very_high.

# %% [markdown]
# ## Normal Imbalance
#
# Zunächst die Ergebnisse für normal imbalance, also die hardcoded Hierarchie ohne zusätzliche Änderungen.

# %%
normal_imb_df = pd.read_csv('result_split/gini_accuracy_all_runs.csv')
normal_imb_df["Method"] = normal_imb_df["Method"].apply(lambda x: "SPH+CPI" if x=="Tailored Approach" else x)
normal_imb_df
# Out:
#       R_e       A@e   Method  gini  p value  Run  SPH Executed  info loss  \
# 0       1  0.386667      SPH  -1.0    -1.00  1.0           8.0       0.25
# 1       2  0.546667      SPH  -1.0    -1.00  1.0           8.0       0.25
# 2       3  0.640000      SPH  -1.0    -1.00  1.0           8.0       0.25
# 3       4  0.740000      SPH  -1.0    -1.00  1.0           8.0       0.25
# 4       5  0.783333      SPH  -1.0    -1.00  1.0           8.0       0.25
# ...   ...       ...      ...   ...      ...  ...           ...        ...
# 2495    6  0.776667  SPH+CPI   0.4     0.95  5.0          10.0       0.25
# 2496    7  0.800000  SPH+CPI   0.4     0.95  5.0          10.0       0.25
# 2497    8  0.823333  SPH+CPI   0.4     0.95  5.0          10.0       0.25
# 2498    9  0.833333  SPH+CPI   0.4     0.95  5.0          10.0       0.25
# 2499   10  0.843333  SPH+CPI   0.4     0.95  5.0          10.0       0.25
#
#        SPH A@1  RF+B A@1   CPI A@1  Avg Acc SPH+CPI
# 0          NaN       NaN       NaN              NaN
# 1          NaN       NaN       NaN              NaN
# 2          NaN       NaN       NaN              NaN
# 3          NaN       NaN       NaN              NaN
# 4          NaN       NaN       NaN              NaN
# ...        ...       ...       ...              ...
# 2495  0.383333  0.336667  0.156667         0.719333
# 2496  0.383333  0.336667  0.156667         0.719333
# 2497  0.383333  0.336667  0.156667         0.719333
# 2498  0.383333  0.336667  0.156667         0.719333
# 2499  0.383333  0.336667  0.156667         0.719333
#
# [2500 rows x 12 columns]

# %%
# get run and parameters with maximum average accuracy
#normal_imb_df["Method"]
best_result = normal_imb_df[normal_imb_df["Avg Acc SPH+CPI"] == normal_imb_df["Avg Acc SPH+CPI"].max()]
best_gini = best_result["gini"].values[0]
best_p = best_result["p value"].values[0]
best_run = best_result["Run"].values[0]

best_ta_methods = normal_imb_df[((normal_imb_df["gini"] ==best_gini) & (normal_imb_df["Run"] == best_run) & (normal_imb_df["p value"] == best_p))]
best_other_methods = normal_imb_df[(normal_imb_df["Run"] == best_run) & (normal_imb_df["gini"] == -1)]
best_all_methods = pd.concat([best_ta_methods, best_other_methods])
best_result
# Out:
#      R_e       A@e   Method  gini  p value  Run  SPH Executed  info loss  \
# 450    1  0.403333  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 451    2  0.573333  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 452    3  0.640000  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 453    4  0.736667  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 454    5  0.783333  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 455    6  0.810000  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 456    7  0.830000  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 457    8  0.833333  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 458    9  0.856667  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 459   10  0.866667  SPH+CPI   0.4     0.85  1.0           8.0       0.25
#
#       SPH A@1  RF+B A@1   CPI A@1  Avg Acc SPH+CPI
# 450  0.386667  0.303333  0.293333         0.733333
# 451  0.386667  0.303333  0.293333         0.733333
# 452  0.386667  0.303333  0.293333         0.733333
# 453  0.386667  0.303333  0.293333         0.733333
# 454  0.386667  0.303333  0.293333         0.733333
# 455  0.386667  0.303333  0.293333         0.733333
# 456  0.386667  0.303333  0.293333         0.733333
# 457  0.386667  0.303333  0.293333         0.733333
# 458  0.386667  0.303333  0.293333         0.733333
# 459  0.386667  0.303333  0.293333         0.733333

# %% [markdown]
# ### Untersuchung von Einfluss Parameter und Runs
#
# Zunächst untersuchen wir, was die besten Parameter und der beste Run ist und schauen uns das Ergebnis dafür an.

# %%
best_params = normal_imb_df[((normal_imb_df["gini"] == best_gini) & (normal_imb_df["p value"] == best_p)) | (normal_imb_df["gini"] ==-1)]
best_run_df = normal_imb_df[normal_imb_df["Run"] == best_run]
ax = sns.lineplot(x="R_e", y="A@e", data=best_all_methods, hue="Method")
write_values_lineplot(best_all_methods, ax)

# %% [markdown]
# Nun schauen wir uns für die besten Parameter an, wie die Ergebnisse über die verschiedenen Runs sind. Dabei sieht man, dass auch für unterschiedliche Runs (also train/test splits) die besten Parameter unterschiedliche Ergebnisse erzielen können. SPH+CPI und SPH sind nun ungefähr gleich auf, aber trotzdem beide noch deutlich besser als RF+B.

# %%
def write_values_lineplot(df, ax):
    palette = sns.color_palette()[0:5]
    color_per_label = {x:c for x,c in zip(df["Method"].unique(), palette)}

    for item, color in zip(df.groupby('Method'),palette):
        #item[1] is a grouped data frame
        for x,y,method in item[1][['R_e','A@e','Method']].values:
            y = np.mean(y)
            ax.text(x,y,f'{y:.2f}', color=color_per_label[method])
            
ax = sns.lineplot(x="R_e", y="A@e", data=best_params, hue="Method", markers=True)
write_values_lineplot(best_params, ax)

# %% [markdown]
# Und jetzt noch wie die Ergebnisse sind, wenn wir den gleichen Run nehmen, aber unterschiedliche Parameter. D.h. wie sich die Parameter auswirken können auf SPH+CPI. Hier sieht man nun, dass SPH+CPI nicht mehr besser ist als SPH (im median) und somit haben die Parameter einen starken Einfluss auf SPH+CPI, was wiederun heißt, dass die Parameteroptimierung schon wichtig ist.

# %%
sns.lineplot(x="R_e", y="A@e", data=best_run_df, hue="Method")

# %% [markdown]
# ## Beste Parameter von normal im Vergleich zu anderen Imbalance Degrees
# Hier mergen wir alle Ergebnisse für very_low, low, normal, high und very_high und schauen uns die Ergebnisse an, wenn wir die besten Parameter für normal nehmen.

# %%
low_imb_df = pd.read_csv('imbalance_degree/low/result_split/gini_accuracy_all_runs.csv')
very_low_imb_df = pd.read_csv('imbalance_degree/very_low/result_split/gini_accuracy_all_runs.csv')
high_imb_df = pd.read_csv('imbalance_degree/high/result_split/gini_accuracy_all_runs.csv')
very_high_imb_df = pd.read_csv('imbalance_degree/very_high/result_split/gini_accuracy_all_runs.csv')


low_imb_df["imbalance"] = "low"
very_low_imb_df["imbalance"] = "very low"
normal_imb_df["imbalance"] = "normal"
high_imb_df["imbalance"] = "high"
very_high_imb_df["imbalance"] = "very high"
very_high_imb_df
# Out:
#       R_e       A@e             Method  gini  p value  Run  SPH Executed  \
# 0       1  0.553333                SPH  -1.0    -1.00  1.0          13.0
# 1       2  0.623333                SPH  -1.0    -1.00  1.0          13.0
# 2       3  0.656667                SPH  -1.0    -1.00  1.0          13.0
# 3       4  0.690000                SPH  -1.0    -1.00  1.0          13.0
# 4       5  0.700000                SPH  -1.0    -1.00  1.0          13.0
# ...   ...       ...                ...   ...      ...  ...           ...
# 2495    6  0.730000  Tailored Approach   0.4     0.95  5.0          10.0
# 2496    7  0.753333  Tailored Approach   0.4     0.95  5.0          10.0
# 2497    8  0.763333  Tailored Approach   0.4     0.95  5.0          10.0
# 2498    9  0.776667  Tailored Approach   0.4     0.95  5.0          10.0
# 2499   10  0.800000  Tailored Approach   0.4     0.95  5.0          10.0
#
#       info loss   SPH A@1  RF+B A@1  CPI A@1  Avg Acc SPH+CPI  imbalance
# 0          0.25       NaN       NaN      NaN              NaN  very high
# 1          0.25       NaN       NaN      NaN              NaN  very high
# 2          0.25       NaN       NaN      NaN              NaN  very high
# 3          0.25       NaN       NaN      NaN              NaN  very high
# 4          0.25       NaN       NaN      NaN              NaN  very high
# ...         ...       ...       ...      ...              ...        ...
# 2495       0.25  0.536667      0.48     0.34         0.690667  very high
# 2496       0.25  0.536667      0.48     0.34         0.690667  very high
# 2497       0.25  0.536667      0.48     0.34         0.690667  very high
# 2498       0.25  0.536667      0.48     0.34         0.690667  very high
# 2499       0.25  0.536667      0.48     0.34         0.690667  very high
#
# [2500 rows x 13 columns]

# %% [markdown]
# Nun werden alle gemerged und nach den besten Parametern von normal gefiltert.

# %%
merged_df = pd.concat([low_imb_df, normal_imb_df, very_low_imb_df, high_imb_df, very_high_imb_df])

merged_df["Method"] = merged_df["Method"].apply(lambda x: "SPH+CPI" if x=="Tailored Approach" else x)

best_merged_df = merged_df[(merged_df["gini"] == best_gini) & (merged_df["p value"] == best_p)]
best_merged_df
# Out:
#       R_e       A@e   Method  gini  p value  Run  SPH Executed  info loss  \
# 450     1  0.256667  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 451     2  0.386667  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 452     3  0.480000  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 453     4  0.553333  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 454     5  0.590000  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# ...   ...       ...      ...   ...      ...  ...           ...        ...
# 2455    6  0.746667  SPH+CPI   0.4     0.85  5.0          10.0       0.25
# 2456    7  0.766667  SPH+CPI   0.4     0.85  5.0          10.0       0.25
# 2457    8  0.773333  SPH+CPI   0.4     0.85  5.0          10.0       0.25
# 2458    9  0.780000  SPH+CPI   0.4     0.85  5.0          10.0       0.25
# 2459   10  0.796667  SPH+CPI   0.4     0.85  5.0          10.0       0.25
#
#        SPH A@1  RF+B A@1  CPI A@1  Avg Acc SPH+CPI  imbalance
# 450   0.236667      0.21     0.18         0.563667        low
# 451   0.236667      0.21     0.18         0.563667        low
# 452   0.236667      0.21     0.18         0.563667        low
# 453   0.236667      0.21     0.18         0.563667        low
# 454   0.236667      0.21     0.18         0.563667        low
# ...        ...       ...      ...              ...        ...
# 2455  0.536667      0.48     0.46         0.700667  very high
# 2456  0.536667      0.48     0.46         0.700667  very high
# 2457  0.536667      0.48     0.46         0.700667  very high
# 2458  0.536667      0.48     0.46         0.700667  very high
# 2459  0.536667      0.48     0.46         0.700667  very high
#
# [250 rows x 13 columns]

# %% [markdown]
# Ergbnis bzgl. Accuracy wird nun visualisiert.
# Man sieht, dass mit steigern imabalance auch die Accuracy (zumindest A@1) steigt und genau andersrum, dass mit sinkender imbalance die Accuracy sinkt.

# %%
#ax = sns.lineplot(x="R_e", y="A@e", hue="imbalance", data=best_merged_df,  markers=True, palette=palette)
print(best_merged_df.head())
line_plot_write_imb_values(best_merged_df)
# Out:
#      R_e       A@e   Method  gini  p value  Run  SPH Executed  info loss  \
# 450    1  0.256667  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 451    2  0.386667  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 452    3  0.480000  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 453    4  0.553333  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 454    5  0.590000  SPH+CPI   0.4     0.85  1.0           8.0       0.25
#
#       SPH A@1  RF+B A@1  CPI A@1  Avg Acc SPH+CPI imbalance
# 450  0.236667      0.21     0.18         0.563667       low
# 451  0.236667      0.21     0.18         0.563667       low
# 452  0.236667      0.21     0.18         0.563667       low
# 453  0.236667      0.21     0.18         0.563667       low
# 454  0.236667      0.21     0.18         0.563667       low
# ['low' nan 'very low' 'high' 'very high']
# 5
# ['low', NaN, 'very low', 'high', 'very high']
# Categories (4, object): ['low' < 'very low' < 'high' < 'very high']
# <ipython-input-82-f82b6e409d45>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["imbalance"] = pd.Categorical(df["imbalance"],
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-805fc2c7066c> in <module>
#       1 #ax = sns.lineplot(x="R_e", y="A@e", hue="imbalance", data=best_merged_df,  markers=True, palette=palette)
#       2 print(best_merged_df.head())
# ----> 3 line_plot_write_imb_values(best_merged_df)
#
# <ipython-input-82-f82b6e409d45> in line_plot_write_imb_values(df)
#       9     df = df.sort_values("imbalance")
#      10     color_per_label = {x:c for x,c in zip(df["imbalance"].unique(), palette)}
# ---> 11     ax = sns.lineplot(x="R_e", y="A@e", hue="imbalance", data=df, markers=True, palette=palette)
#      12
#      13     for item, color in zip(df.groupby('imbalance'),palette):
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#    1118              legend="brief", ax=None, **kwargs):
#    1119
# -> 1120     p = _LinePlotter(
#    1121         x=x, y=y, hue=hue, size=size, style=style, data=data,
#    1122         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     700         )
#     701
# --> 702         self.parse_hue(plot_data["hue"], palette, hue_order, hue_norm)
#     703         self.parse_size(plot_data["size"], sizes, size_order, size_norm)
#     704         self.parse_style(plot_data["style"], markers, dashes, style_order)
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in parse_hue(self, data, palette, order, norm)
#     367             cmap = None
#     368             limits = None
# --> 369             levels, palette = self.categorical_to_palette(
#     370                 # List comprehension here is required to
#     371                 # overcome differences in the way pandas
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in categorical_to_palette(self, data, order, palette)
#     214                 if len(palette) != n_colors:
#     215                     err = "The palette list has the wrong number of colors."
# --> 216                     raise ValueError(err)
#     217                 colors = palette
#     218             else:
#
# ValueError: The palette list has the wrong number of colors.

# %%
best_merged_df_sph = merged_df[(merged_df["gini"] == -1) & (merged_df["p value"] == -1) & (merged_df["Run"] == best_run) & (merged_df["Method"]=="SPH")]
best_merged_df_sph
# Out:
#    R_e       A@e Method  gini  p value  Run  SPH Executed  info loss  SPH A@1  \
# 0    1  0.236667    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 1    2  0.383333    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 2    3  0.463333    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 3    4  0.550000    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 4    5  0.580000    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 5    6  0.603333    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 6    7  0.646667    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 7    8  0.666667    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 8    9  0.696667    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 9   10  0.710000    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 0    1  0.386667    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 1    2  0.546667    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 2    3  0.640000    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 3    4  0.740000    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 4    5  0.783333    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 5    6  0.806667    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 6    7  0.823333    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 7    8  0.830000    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 8    9  0.853333    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 9   10  0.866667    SPH  -1.0     -1.0  1.0           8.0       0.25      NaN
# 0    1  0.190000    SPH  -1.0     -1.0  1.0           6.0       0.25      NaN
# 1    2  0.276667    SPH  -1.0     -1.0  1.0           6.0       0.25      NaN
# 2    3  0.360000    SPH  -1.0     -1.0  1.0           6.0       0.25      NaN
# 3    4  0.433333    SPH  -1.0     -1.0  1.0           6.0       0.25      NaN
# 4    5  0.486667    SPH  -1.0     -1.0  1.0           6.0       0.25      NaN
# 5    6  0.523333    SPH  -1.0     -1.0  1.0           6.0       0.25      NaN
# 6    7  0.556667    SPH  -1.0     -1.0  1.0           6.0       0.25      NaN
# 7    8  0.593333    SPH  -1.0     -1.0  1.0           6.0       0.25      NaN
# 8    9  0.613333    SPH  -1.0     -1.0  1.0           6.0       0.25      NaN
# 9   10  0.623333    SPH  -1.0     -1.0  1.0           6.0       0.25      NaN
# 0    1  0.486667    SPH  -1.0     -1.0  1.0          10.0       0.25      NaN
# 1    2  0.616667    SPH  -1.0     -1.0  1.0          10.0       0.25      NaN
# 2    3  0.696667    SPH  -1.0     -1.0  1.0          10.0       0.25      NaN
# 3    4  0.723333    SPH  -1.0     -1.0  1.0          10.0       0.25      NaN
# 4    5  0.756667    SPH  -1.0     -1.0  1.0          10.0       0.25      NaN
# 5    6  0.780000    SPH  -1.0     -1.0  1.0          10.0       0.25      NaN
# 6    7  0.800000    SPH  -1.0     -1.0  1.0          10.0       0.25      NaN
# 7    8  0.810000    SPH  -1.0     -1.0  1.0          10.0       0.25      NaN
# 8    9  0.816667    SPH  -1.0     -1.0  1.0          10.0       0.25      NaN
# 9   10  0.830000    SPH  -1.0     -1.0  1.0          10.0       0.25      NaN
# 0    1  0.553333    SPH  -1.0     -1.0  1.0          13.0       0.25      NaN
# 1    2  0.623333    SPH  -1.0     -1.0  1.0          13.0       0.25      NaN
# 2    3  0.656667    SPH  -1.0     -1.0  1.0          13.0       0.25      NaN
# 3    4  0.690000    SPH  -1.0     -1.0  1.0          13.0       0.25      NaN
# 4    5  0.700000    SPH  -1.0     -1.0  1.0          13.0       0.25      NaN
# 5    6  0.726667    SPH  -1.0     -1.0  1.0          13.0       0.25      NaN
# 6    7  0.750000    SPH  -1.0     -1.0  1.0          13.0       0.25      NaN
# 7    8  0.770000    SPH  -1.0     -1.0  1.0          13.0       0.25      NaN
# 8    9  0.786667    SPH  -1.0     -1.0  1.0          13.0       0.25      NaN
# 9   10  0.800000    SPH  -1.0     -1.0  1.0          13.0       0.25      NaN
#
#    RF+B A@1  CPI A@1  Avg Acc SPH+CPI  imbalance
# 0       NaN      NaN              NaN        low
# 1       NaN      NaN              NaN        low
# 2       NaN      NaN              NaN        low
# 3       NaN      NaN              NaN        low
# 4       NaN      NaN              NaN        low
# 5       NaN      NaN              NaN        low
# 6       NaN      NaN              NaN        low
# 7       NaN      NaN              NaN        low
# 8       NaN      NaN              NaN        low
# 9       NaN      NaN              NaN        low
# 0       NaN      NaN              NaN        NaN
# 1       NaN      NaN              NaN        NaN
# 2       NaN      NaN              NaN        NaN
# 3       NaN      NaN              NaN        NaN
# 4       NaN      NaN              NaN        NaN
# 5       NaN      NaN              NaN        NaN
# 6       NaN      NaN              NaN        NaN
# 7       NaN      NaN              NaN        NaN
# 8       NaN      NaN              NaN        NaN
# 9       NaN      NaN              NaN        NaN
# 0       NaN      NaN              NaN   very low
# 1       NaN      NaN              NaN   very low
# 2       NaN      NaN              NaN   very low
# 3       NaN      NaN              NaN   very low
# 4       NaN      NaN              NaN   very low
# 5       NaN      NaN              NaN   very low
# 6       NaN      NaN              NaN   very low
# 7       NaN      NaN              NaN   very low
# 8       NaN      NaN              NaN   very low
# 9       NaN      NaN              NaN   very low
# 0       NaN      NaN              NaN       high
# 1       NaN      NaN              NaN       high
# 2       NaN      NaN              NaN       high
# 3       NaN      NaN              NaN       high
# 4       NaN      NaN              NaN       high
# 5       NaN      NaN              NaN       high
# 6       NaN      NaN              NaN       high
# 7       NaN      NaN              NaN       high
# 8       NaN      NaN              NaN       high
# 9       NaN      NaN              NaN       high
# 0       NaN      NaN              NaN  very high
# 1       NaN      NaN              NaN  very high
# 2       NaN      NaN              NaN  very high
# 3       NaN      NaN              NaN  very high
# 4       NaN      NaN              NaN  very high
# 5       NaN      NaN              NaN  very high
# 6       NaN      NaN              NaN  very high
# 7       NaN      NaN              NaN  very high
# 8       NaN      NaN              NaN  very high
# 9       NaN      NaN              NaN  very high

# %% [markdown]
# Accuracy für verschiedene imbalance degrees für SPH. Hier sehen wir, dass die Accuracy sehr ähnlich ist zu SPH+CPI, aber auch daran liegt, dass wir die PArameter von CPI nicht optimieren.

# %%
line_plot_write_imb_values(best_merged_df_sph)
# Out:
# ['low' nan 'very low' 'high' 'very high']
# 5
# ['low', NaN, 'very low', 'high', 'very high']
# Categories (4, object): ['low' < 'very low' < 'high' < 'very high']
# <ipython-input-82-f82b6e409d45>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["imbalance"] = pd.Categorical(df["imbalance"],
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-0a7d2085c8e2> in <module>
# ----> 1 line_plot_write_imb_values(best_merged_df_sph)
#
# <ipython-input-82-f82b6e409d45> in line_plot_write_imb_values(df)
#       9     df = df.sort_values("imbalance")
#      10     color_per_label = {x:c for x,c in zip(df["imbalance"].unique(), palette)}
# ---> 11     ax = sns.lineplot(x="R_e", y="A@e", hue="imbalance", data=df, markers=True, palette=palette)
#      12
#      13     for item, color in zip(df.groupby('imbalance'),palette):
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#    1118              legend="brief", ax=None, **kwargs):
#    1119
# -> 1120     p = _LinePlotter(
#    1121         x=x, y=y, hue=hue, size=size, style=style, data=data,
#    1122         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     700         )
#     701
# --> 702         self.parse_hue(plot_data["hue"], palette, hue_order, hue_norm)
#     703         self.parse_size(plot_data["size"], sizes, size_order, size_norm)
#     704         self.parse_style(plot_data["style"], markers, dashes, style_order)
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in parse_hue(self, data, palette, order, norm)
#     367             cmap = None
#     368             limits = None
# --> 369             levels, palette = self.categorical_to_palette(
#     370                 # List comprehension here is required to
#     371                 # overcome differences in the way pandas
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in categorical_to_palette(self, data, order, palette)
#     214                 if len(palette) != n_colors:
#     215                     err = "The palette list has the wrong number of colors."
# --> 216                     raise ValueError(err)
#     217                 colors = palette
#     218             else:
#
# ValueError: The palette list has the wrong number of colors.

# %%
best_merged_df_sph_Rf = merged_df[(merged_df["gini"] == -1) & (merged_df["p value"] == -1) & (merged_df["Run"] == best_run) & (merged_df["Method"]=="RF+B")]
best_merged_df_sph_Rf
line_plot_write_imb_values(best_merged_df_sph_Rf)
# Out:
# ['low' 'normal' 'very low' 'high' 'very high']
# 5
# ['low', 'normal', 'very low', 'high', 'very high']
# Categories (5, object): ['normal' < 'low' < 'very low' < 'high' < 'very high']
# <ipython-input-82-f82b6e409d45>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["imbalance"] = pd.Categorical(df["imbalance"],

# %%
def line_plot_write_imb_values(df):
    print(df["imbalance"].unique())
    df["imbalance"] = pd.Categorical(df["imbalance"], 
                      categories=["normal","low","very low","high", "very high"],
                      ordered=True)
    palette = sns.color_palette()[0:len(df["imbalance"].unique())]
    print(len(palette))
    print(df["imbalance"].unique())
    df = df.sort_values("imbalance")
    color_per_label = {x:c for x,c in zip(df["imbalance"].unique(), palette)}
    ax = sns.lineplot(x="R_e", y="A@e", hue="imbalance", data=df, markers=True, palette=palette)

    for item, color in zip(df.groupby('imbalance'),palette):
        #item[1] is a grouped data frame
        for x,y,imb in item[1][['R_e','A@e','imbalance']].values:
            ax.text(x,y,f'{y:.2f}', color=color_per_label[imb])

# %% [markdown]
# ## Accuracy für jeden imbalance degree optimiert
#
# Jetzt schauen wir uns die Accuracy für die verschiedenen imbalance degrees an, wenn wir jeweils die Parameter für jeden einzeln optimieren

# %%
best_result_each_degree = pd.DataFrame()

frames = [very_low_imb_df, low_imb_df, normal_imb_df, high_imb_df, very_high_imb_df]
for frame in frames:    
    best_result = frame[frame["Avg Acc SPH+CPI"] == frame["Avg Acc SPH+CPI"].max()]
    print(best_result)
    best_gini = best_result["gini"].values[0]
    best_p = best_result["p value"].values[0]
    best_run = best_result["Run"].values[0]
    # best result for SPH+CPI
    best_ta_methods = frame[((frame["gini"] ==best_gini) & (frame["Run"] == best_run) & (frame["p value"] == best_p))]
    best_result_each_degree = pd.concat([best_result_each_degree, best_ta_methods])
    
best_result_each_degree
# Out:
#       R_e       A@e             Method  gini  p value  Run  SPH Executed  \
# 1730    1  0.196667  Tailored Approach   0.3     0.90  4.0           9.0
# 1731    2  0.313333  Tailored Approach   0.3     0.90  4.0           9.0
# 1732    3  0.383333  Tailored Approach   0.3     0.90  4.0           9.0
# 1733    4  0.450000  Tailored Approach   0.3     0.90  4.0           9.0
# 1734    5  0.503333  Tailored Approach   0.3     0.90  4.0           9.0
# ...   ...       ...                ...   ...      ...  ...           ...
# 1995    6  0.550000  Tailored Approach   0.4     0.95  4.0           9.0
# 1996    7  0.580000  Tailored Approach   0.4     0.95  4.0           9.0
# 1997    8  0.593333  Tailored Approach   0.4     0.95  4.0           9.0
# 1998    9  0.613333  Tailored Approach   0.4     0.95  4.0           9.0
# 1999   10  0.636667  Tailored Approach   0.4     0.95  4.0           9.0
#
#       info loss   SPH A@1  RF+B A@1   CPI A@1  Avg Acc SPH+CPI imbalance
# 1730       0.25  0.196667      0.11  0.096667            0.482  very low
# 1731       0.25  0.196667      0.11  0.096667            0.482  very low
# 1732       0.25  0.196667      0.11  0.096667            0.482  very low
# 1733       0.25  0.196667      0.11  0.096667            0.482  very low
# 1734       0.25  0.196667      0.11  0.096667            0.482  very low
# ...         ...       ...       ...       ...              ...       ...
# 1995       0.25  0.196667      0.11  0.110000            0.482  very low
# 1996       0.25  0.196667      0.11  0.110000            0.482  very low
# 1997       0.25  0.196667      0.11  0.110000            0.482  very low
# 1998       0.25  0.196667      0.11  0.110000            0.482  very low
# 1999       0.25  0.196667      0.11  0.110000            0.482  very low
#
# [140 rows x 13 columns]
#     R_e       A@e             Method  gini  p value  Run  SPH Executed  \
# 30    1  0.270000  Tailored Approach  0.25      0.7  1.0           8.0
# 31    2  0.400000  Tailored Approach  0.25      0.7  1.0           8.0
# 32    3  0.483333  Tailored Approach  0.25      0.7  1.0           8.0
# 33    4  0.543333  Tailored Approach  0.25      0.7  1.0           8.0
# 34    5  0.580000  Tailored Approach  0.25      0.7  1.0           8.0
# 35    6  0.616667  Tailored Approach  0.25      0.7  1.0           8.0
# 36    7  0.660000  Tailored Approach  0.25      0.7  1.0           8.0
# 37    8  0.693333  Tailored Approach  0.25      0.7  1.0           8.0
# 38    9  0.720000  Tailored Approach  0.25      0.7  1.0           8.0
# 39   10  0.730000  Tailored Approach  0.25      0.7  1.0           8.0
#
#     info loss   SPH A@1  RF+B A@1   CPI A@1  Avg Acc SPH+CPI imbalance
# 30       0.25  0.236667      0.21  0.206667         0.569667       low
# 31       0.25  0.236667      0.21  0.206667         0.569667       low
# 32       0.25  0.236667      0.21  0.206667         0.569667       low
# 33       0.25  0.236667      0.21  0.206667         0.569667       low
# 34       0.25  0.236667      0.21  0.206667         0.569667       low
# 35       0.25  0.236667      0.21  0.206667         0.569667       low
# 36       0.25  0.236667      0.21  0.206667         0.569667       low
# 37       0.25  0.236667      0.21  0.206667         0.569667       low
# 38       0.25  0.236667      0.21  0.206667         0.569667       low
# 39       0.25  0.236667      0.21  0.206667         0.569667       low
#      R_e       A@e   Method  gini  p value  Run  SPH Executed  info loss  \
# 450    1  0.403333  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 451    2  0.573333  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 452    3  0.640000  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 453    4  0.736667  SPH+CPI   0.4     0.85  1.0           8.0       0.25
# 454    5  0.783333  SPH+CPI   0.4     0.85  1.0           8.0       0.25
#       info loss  SPH A@1  RF+B A@1   CPI A@1  Avg Acc SPH+CPI  imbalance
# 1210       0.25     0.55  0.483333  0.426667            0.721  very high
# 1211       0.25     0.55  0.483333  0.426667            0.721  very high
# 1212       0.25     0.55  0.483333  0.426667            0.721  very high
# 1213       0.25     0.55  0.483333  0.426667            0.721  very high
# 1214       0.25     0.55  0.483333  0.426667            0.721  very high
# 1215       0.25     0.55  0.483333  0.426667            0.721  very high
# 1216       0.25     0.55  0.483333  0.426667            0.721  very high
# 1217       0.25     0.55  0.483333  0.426667            0.721  very high
# 1218       0.25     0.55  0.483333  0.426667            0.721  very high
# 1219       0.25     0.55  0.483333  0.426667            0.721  very high
# 1330       0.25     0.55  0.483333  0.426667            0.721  very high
# 1331       0.25     0.55  0.483333  0.426667            0.721  very high
# 1332       0.25     0.55  0.483333  0.426667            0.721  very high
# 1333       0.25     0.55  0.483333  0.426667            0.721  very high
# 1334       0.25     0.55  0.483333  0.426667            0.721  very high
# 1335       0.25     0.55  0.483333  0.426667            0.721  very high
# 1336       0.25     0.55  0.483333  0.426667            0.721  very high
# 1337       0.25     0.55  0.483333  0.426667            0.721  very high
# 1338       0.25     0.55  0.483333  0.426667            0.721  very high
# 1339       0.25     0.55  0.483333  0.426667            0.721  very high
# 1450       0.25     0.55  0.483333  0.426667            0.721  very high
# 1451       0.25     0.55  0.483333  0.426667            0.721  very high
# 1452       0.25     0.55  0.483333  0.426667            0.721  very high
# 1453       0.25     0.55  0.483333  0.426667            0.721  very high
# 1454       0.25     0.55  0.483333  0.426667            0.721  very high
# 1455       0.25     0.55  0.483333  0.426667            0.721  very high
# 1456       0.25     0.55  0.483333  0.426667            0.721  very high
# 1457       0.25     0.55  0.483333  0.426667            0.721  very high
# 1458       0.25     0.55  0.483333  0.426667            0.721  very high
# 1459       0.25     0.55  0.483333  0.426667            0.721  very high
#       R_e       A@e             Method  gini  p value  Run  SPH Executed  \
# 1730    1  0.196667  Tailored Approach  0.30     0.90  4.0           9.0
# 1731    2  0.313333  Tailored Approach  0.30     0.90  4.0           9.0
# 1732    3  0.383333  Tailored Approach  0.30     0.90  4.0           9.0
# 1733    4  0.450000  Tailored Approach  0.30     0.90  4.0           9.0
# 1734    5  0.503333  Tailored Approach  0.30     0.90  4.0           9.0
# 1735    6  0.550000  Tailored Approach  0.30     0.90  4.0           9.0
# 1736    7  0.580000  Tailored Approach  0.30     0.90  4.0           9.0
# 1737    8  0.593333  Tailored Approach  0.30     0.90  4.0           9.0
# 1738    9  0.613333  Tailored Approach  0.30     0.90  4.0           9.0
# 1739   10  0.636667  Tailored Approach  0.30     0.90  4.0           9.0
# 30      1  0.270000  Tailored Approach  0.25     0.70  1.0           8.0
# 31      2  0.400000  Tailored Approach  0.25     0.70  1.0           8.0
# 32      3  0.483333  Tailored Approach  0.25     0.70  1.0           8.0
# 33      4  0.543333  Tailored Approach  0.25     0.70  1.0           8.0
# 1736       0.25  0.196667  0.110000  0.096667         0.482000   very low
# 1737       0.25  0.196667  0.110000  0.096667         0.482000   very low
# 1738       0.25  0.196667  0.110000  0.096667         0.482000   very low
# 1739       0.25  0.196667  0.110000  0.096667         0.482000   very low
# 30         0.25  0.236667  0.210000  0.206667         0.569667        low
# 31         0.25  0.236667  0.210000  0.206667         0.569667        low
# 32         0.25  0.236667  0.210000  0.206667         0.569667        low
# 33         0.25  0.236667  0.210000  0.206667         0.569667        low
# 34         0.25  0.236667  0.210000  0.206667         0.569667        low
# 35         0.25  0.236667  0.210000  0.206667         0.569667        low
# 36         0.25  0.236667  0.210000  0.206667         0.569667        low
# 37         0.25  0.236667  0.210000  0.206667         0.569667        low
# 38         0.25  0.236667  0.210000  0.206667         0.569667        low
# 39         0.25  0.236667  0.210000  0.206667         0.569667        low
# 450        0.25  0.386667  0.303333  0.293333         0.733333     normal
# 451        0.25  0.386667  0.303333  0.293333         0.733333     normal
# 452        0.25  0.386667  0.303333  0.293333         0.733333     normal
# 453        0.25  0.386667  0.303333  0.293333         0.733333     normal
# 454        0.25  0.386667  0.303333  0.293333         0.733333     normal
# 455        0.25  0.386667  0.303333  0.293333         0.733333     normal
# 456        0.25  0.386667  0.303333  0.293333         0.733333     normal
# 457        0.25  0.386667  0.303333  0.293333         0.733333     normal
# 458        0.25  0.386667  0.303333  0.293333         0.733333     normal
# 459        0.25  0.386667  0.303333  0.293333         0.733333     normal
# 450        0.25  0.486667  0.416667  0.410000         0.725333       high
# 451        0.25  0.486667  0.416667  0.410000         0.725333       high
# 452        0.25  0.486667  0.416667  0.410000         0.725333       high
# 453        0.25  0.486667  0.416667  0.410000         0.725333       high
# 454        0.25  0.486667  0.416667  0.410000         0.725333       high
# 455        0.25  0.486667  0.416667  0.410000         0.725333       high
# 456        0.25  0.486667  0.416667  0.410000         0.725333       high
# 457        0.25  0.486667  0.416667  0.410000         0.725333       high
# 458        0.25  0.486667  0.416667  0.410000         0.725333       high
# 459        0.25  0.486667  0.416667  0.410000         0.725333       high
# 1210       0.25  0.550000  0.483333  0.426667         0.721000  very high
# 1211       0.25  0.550000  0.483333  0.426667         0.721000  very high
# 1212       0.25  0.550000  0.483333  0.426667         0.721000  very high
# 1213       0.25  0.550000  0.483333  0.426667         0.721000  very high
# 1214       0.25  0.550000  0.483333  0.426667         0.721000  very high
# 1215       0.25  0.550000  0.483333  0.426667         0.721000  very high
# 1216       0.25  0.550000  0.483333  0.426667         0.721000  very high
# 1217       0.25  0.550000  0.483333  0.426667         0.721000  very high
# 1218       0.25  0.550000  0.483333  0.426667         0.721000  very high
# 1219       0.25  0.550000  0.483333  0.426667         0.721000  very high

# %%
line_plot_write_imb_values(best_result_each_degree)
# Out:
# ['very low' 'low' 'normal' 'high' 'very high']
# 5
# ['very low', 'low', 'normal', 'high', 'very high']
# Categories (5, object): ['normal' < 'low' < 'very low' < 'high' < 'very high']
