# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("result_split/gini_accuracy_all_runs.csv")
df["Method"] = df["Method"].apply(lambda x: "SPH+CPI" if x=="Tailored Approach" else x)

# %%
df
# Out:
#     R_e       A@e   Method  gini  p value  Run  SPH Executed  info loss  \
# 0     1  0.386667      SPH  -1.0    -1.00  1.0           8.0       0.25
# 1     2  0.546667      SPH  -1.0    -1.00  1.0           8.0       0.25
# 2     3  0.640000      SPH  -1.0    -1.00  1.0           8.0       0.25
# 3     4  0.740000      SPH  -1.0    -1.00  1.0           8.0       0.25
# 4     5  0.783333      SPH  -1.0    -1.00  1.0           8.0       0.25
# 5     6  0.806667      SPH  -1.0    -1.00  1.0           8.0       0.25
# 6     7  0.823333      SPH  -1.0    -1.00  1.0           8.0       0.25
# 7     8  0.830000      SPH  -1.0    -1.00  1.0           8.0       0.25
# 8     9  0.853333      SPH  -1.0    -1.00  1.0           8.0       0.25
# 9    10  0.866667      SPH  -1.0    -1.00  1.0           8.0       0.25
# 10    1  0.303333     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 11    2  0.436667     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 12    3  0.520000     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 13    4  0.590000     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 14    5  0.670000     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 15    6  0.713333     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 16    7  0.736667     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 17    8  0.743333     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 18    9  0.756667     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 19   10  0.770000     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 20    1  0.193333  SPH+CPI   NaN      NaN  NaN           NaN        NaN
# 21    2  0.263333  SPH+CPI   NaN      NaN  NaN           NaN        NaN
# 22    3  0.336667  SPH+CPI   NaN      NaN  NaN           NaN        NaN
# 23    4  0.403333  SPH+CPI   NaN      NaN  NaN           NaN        NaN
# 24    5  0.463333  SPH+CPI   NaN      NaN  NaN           NaN        NaN
# 25    6  0.536667  SPH+CPI   NaN      NaN  NaN           NaN        NaN
# 26    7  0.596667  SPH+CPI   NaN      NaN  NaN           NaN        NaN
# 27    8  0.653333  SPH+CPI   NaN      NaN  NaN           NaN        NaN
# 28    9  0.690000  SPH+CPI   NaN      NaN  NaN           NaN        NaN
# 29   10  0.723333  SPH+CPI   NaN      NaN  NaN           NaN        NaN
# 30    1  0.403333  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 31    2  0.570000  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 32    3  0.636667  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 33    4  0.736667  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 34    5  0.786667  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 35    6  0.810000  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 36    7  0.830000  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 37    8  0.833333  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 38    9  0.856667  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 39   10  0.866667  SPH+CPI   0.4     0.95  1.0           8.0       0.25
#
#      SPH A@1  RF+B A@1   CPI A@1  Avg Acc SPH+CPI
# 0        NaN       NaN       NaN              NaN
# 1        NaN       NaN       NaN              NaN
# 2        NaN       NaN       NaN              NaN
# 3        NaN       NaN       NaN              NaN
# 4        NaN       NaN       NaN              NaN
# 5        NaN       NaN       NaN              NaN
# 6        NaN       NaN       NaN              NaN
# 7        NaN       NaN       NaN              NaN
# 8        NaN       NaN       NaN              NaN
# 9        NaN       NaN       NaN              NaN
# 10       NaN       NaN       NaN              NaN
# 11       NaN       NaN       NaN              NaN
# 12       NaN       NaN       NaN              NaN
# 13       NaN       NaN       NaN              NaN
# 14       NaN       NaN       NaN              NaN
# 15       NaN       NaN       NaN              NaN
# 16       NaN       NaN       NaN              NaN
# 17       NaN       NaN       NaN              NaN
# 18       NaN       NaN       NaN              NaN
# 19       NaN       NaN       NaN              NaN
# 20       NaN       NaN       NaN              NaN
# 21       NaN       NaN       NaN              NaN
# 22       NaN       NaN       NaN              NaN
# 23       NaN       NaN       NaN              NaN
# 24       NaN       NaN       NaN              NaN
# 25       NaN       NaN       NaN              NaN
# 26       NaN       NaN       NaN              NaN
# 27       NaN       NaN       NaN              NaN
# 28       NaN       NaN       NaN              NaN
# 29       NaN       NaN       NaN              NaN
# 30  0.386667  0.303333  0.193333            0.733
# 31  0.386667  0.303333  0.193333            0.733
# 32  0.386667  0.303333  0.193333            0.733
# 33  0.386667  0.303333  0.193333            0.733
# 34  0.386667  0.303333  0.193333            0.733
# 35  0.386667  0.303333  0.193333            0.733
# 36  0.386667  0.303333  0.193333            0.733
# 37  0.386667  0.303333  0.193333            0.733
# 38  0.386667  0.303333  0.193333            0.733
# 39  0.386667  0.303333  0.193333            0.733

# %%
print(df["Run"].unique())
# Out:
# [10.  1. nan  2.  9.  3.  7.  8.  4.  5.  6.]

# %%
df = df[~df['Run'].isnull()]
df
# Out:
#     R_e       A@e   Method  gini  p value  Run  SPH Executed  info loss  \
# 0     1  0.386667      SPH  -1.0    -1.00  1.0           8.0       0.25
# 1     2  0.546667      SPH  -1.0    -1.00  1.0           8.0       0.25
# 2     3  0.640000      SPH  -1.0    -1.00  1.0           8.0       0.25
# 3     4  0.740000      SPH  -1.0    -1.00  1.0           8.0       0.25
# 4     5  0.783333      SPH  -1.0    -1.00  1.0           8.0       0.25
# 5     6  0.806667      SPH  -1.0    -1.00  1.0           8.0       0.25
# 6     7  0.823333      SPH  -1.0    -1.00  1.0           8.0       0.25
# 7     8  0.830000      SPH  -1.0    -1.00  1.0           8.0       0.25
# 8     9  0.853333      SPH  -1.0    -1.00  1.0           8.0       0.25
# 9    10  0.866667      SPH  -1.0    -1.00  1.0           8.0       0.25
# 10    1  0.303333     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 11    2  0.436667     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 12    3  0.520000     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 13    4  0.590000     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 14    5  0.670000     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 15    6  0.713333     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 16    7  0.736667     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 17    8  0.743333     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 18    9  0.756667     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 19   10  0.770000     RF+B  -1.0    -1.00  1.0           8.0        NaN
# 30    1  0.403333  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 31    2  0.570000  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 32    3  0.636667  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 33    4  0.736667  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 34    5  0.786667  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 35    6  0.810000  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 36    7  0.830000  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 37    8  0.833333  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 38    9  0.856667  SPH+CPI   0.4     0.95  1.0           8.0       0.25
# 39   10  0.866667  SPH+CPI   0.4     0.95  1.0           8.0       0.25
#
#      SPH A@1  RF+B A@1   CPI A@1  Avg Acc SPH+CPI
# 0        NaN       NaN       NaN              NaN
# 1        NaN       NaN       NaN              NaN
# 2        NaN       NaN       NaN              NaN
# 3        NaN       NaN       NaN              NaN
# 4        NaN       NaN       NaN              NaN
# 5        NaN       NaN       NaN              NaN
# 6        NaN       NaN       NaN              NaN
# 7        NaN       NaN       NaN              NaN
# 8        NaN       NaN       NaN              NaN
# 9        NaN       NaN       NaN              NaN
# 10       NaN       NaN       NaN              NaN
# 11       NaN       NaN       NaN              NaN
# 12       NaN       NaN       NaN              NaN
# 13       NaN       NaN       NaN              NaN
# 14       NaN       NaN       NaN              NaN
# 15       NaN       NaN       NaN              NaN
# 16       NaN       NaN       NaN              NaN
# 17       NaN       NaN       NaN              NaN
# 18       NaN       NaN       NaN              NaN
# 19       NaN       NaN       NaN              NaN
# 30  0.386667  0.303333  0.193333            0.733
# 31  0.386667  0.303333  0.193333            0.733
# 32  0.386667  0.303333  0.193333            0.733
# 33  0.386667  0.303333  0.193333            0.733
# 34  0.386667  0.303333  0.193333            0.733
# 35  0.386667  0.303333  0.193333            0.733
# 36  0.386667  0.303333  0.193333            0.733
# 37  0.386667  0.303333  0.193333            0.733
# 38  0.386667  0.303333  0.193333            0.733
# 39  0.386667  0.303333  0.193333            0.733

# %%
df_tap = df

# %%
df_tap['Acc average'] = df_tap.groupby(['Run', 'gini', 'p value', 'Method'])['A@e'].transform('mean')

# %%
df_tap
# Out:
#       R_e       A@e   Method  gini  p value   Run  SPH Executed  info loss  \
# 0       1  0.416667  SPH+CPI  0.25     0.80  10.0           7.0       0.25
# 1       2  0.493333      SPH -1.00    -1.00   1.0           8.0       0.25
# 2       3  0.573333      SPH -1.00    -1.00   1.0           8.0       0.25
# 3       4  0.636667      SPH -1.00    -1.00   1.0           8.0       0.25
# 4       5  0.713333      SPH -1.00    -1.00   1.0           8.0       0.25
# ...   ...       ...      ...   ...      ...   ...           ...        ...
# 4995    6  0.773333  SPH+CPI  0.40     0.95  10.0           7.0       0.25
# 4996    7  0.786667  SPH+CPI  0.40     0.95  10.0           7.0       0.25
# 4997    8  0.793333  SPH+CPI  0.40     0.95  10.0           7.0       0.25
# 4998    9  0.803333  SPH+CPI  0.40     0.95  10.0           7.0       0.25
# 4999   10  0.810000  SPH+CPI  0.40     0.95  10.0           7.0       0.25
#
#        SPH A@1  RF+B A@1  CPI A@1  Acc average
# 0     0.386667  0.323333     0.31     0.708667
# 1          NaN       NaN      NaN     0.659000
# 2          NaN       NaN      NaN     0.659000
# 3          NaN       NaN      NaN     0.659000
# 4          NaN       NaN      NaN     0.659000
# ...        ...       ...      ...          ...
# 4995  0.386667  0.323333     0.17     0.710000
# 4996  0.386667  0.323333     0.17     0.710000
# 4997  0.386667  0.323333     0.17     0.710000
# 4998  0.386667  0.323333     0.17     0.710000
# 4999  0.386667  0.323333     0.17     0.710000
#
# [2600 rows x 12 columns]

# %%
df = pd.read_csv("result_split/gini_accuracy_all_runs.csv")
df = df[~df['Run'].isnull()]

# %%
best_run_df = df[df["Run"] == 1]
#best_run_df["Method"] = df["Method"].apply(lambda x: "SPH+CPI" if x=="Tailored Approach" else x)
sns.lineplot(x="R_e", y="A@e", data=best_run_df, hue="Method", ci="sd")
# Out:
#     R_e       A@e             Method  gini  p value  Run  SPH Executed  \
# 0     1  0.386667                SPH  -1.0    -1.00  1.0           8.0
# 1     2  0.546667                SPH  -1.0    -1.00  1.0           8.0
# 2     3  0.640000                SPH  -1.0    -1.00  1.0           8.0
# 3     4  0.740000                SPH  -1.0    -1.00  1.0           8.0
# 4     5  0.783333                SPH  -1.0    -1.00  1.0           8.0
# 5     6  0.806667                SPH  -1.0    -1.00  1.0           8.0
# 6     7  0.823333                SPH  -1.0    -1.00  1.0           8.0
# 7     8  0.830000                SPH  -1.0    -1.00  1.0           8.0
# 8     9  0.853333                SPH  -1.0    -1.00  1.0           8.0
# 9    10  0.866667                SPH  -1.0    -1.00  1.0           8.0
# 10    1  0.303333               RF+B  -1.0    -1.00  1.0           8.0
# 11    2  0.436667               RF+B  -1.0    -1.00  1.0           8.0
# 12    3  0.520000               RF+B  -1.0    -1.00  1.0           8.0
# 13    4  0.590000               RF+B  -1.0    -1.00  1.0           8.0
# 14    5  0.670000               RF+B  -1.0    -1.00  1.0           8.0
# 15    6  0.713333               RF+B  -1.0    -1.00  1.0           8.0
# 16    7  0.736667               RF+B  -1.0    -1.00  1.0           8.0
# 17    8  0.743333               RF+B  -1.0    -1.00  1.0           8.0
# 18    9  0.756667               RF+B  -1.0    -1.00  1.0           8.0
# 19   10  0.770000               RF+B  -1.0    -1.00  1.0           8.0
# 30    1  0.403333  Tailored Approach   0.4     0.95  1.0           8.0
# 31    2  0.570000  Tailored Approach   0.4     0.95  1.0           8.0
# 32    3  0.636667  Tailored Approach   0.4     0.95  1.0           8.0
# 33    4  0.736667  Tailored Approach   0.4     0.95  1.0           8.0
# 34    5  0.786667  Tailored Approach   0.4     0.95  1.0           8.0
# 35    6  0.810000  Tailored Approach   0.4     0.95  1.0           8.0
# 36    7  0.830000  Tailored Approach   0.4     0.95  1.0           8.0
# 37    8  0.833333  Tailored Approach   0.4     0.95  1.0           8.0
# 38    9  0.856667  Tailored Approach   0.4     0.95  1.0           8.0
# 39   10  0.866667  Tailored Approach   0.4     0.95  1.0           8.0
#
#     info loss   SPH A@1  RF+B A@1   CPI A@1  Avg Acc SPH+CPI
# 0        0.25       NaN       NaN       NaN              NaN
# 1        0.25       NaN       NaN       NaN              NaN
# 2        0.25       NaN       NaN       NaN              NaN
# 3        0.25       NaN       NaN       NaN              NaN
# 4        0.25       NaN       NaN       NaN              NaN
# 5        0.25       NaN       NaN       NaN              NaN
# 6        0.25       NaN       NaN       NaN              NaN
# 7        0.25       NaN       NaN       NaN              NaN
# 8        0.25       NaN       NaN       NaN              NaN
# 9        0.25       NaN       NaN       NaN              NaN
# 10        NaN       NaN       NaN       NaN              NaN
# 11        NaN       NaN       NaN       NaN              NaN
# 12        NaN       NaN       NaN       NaN              NaN
# 13        NaN       NaN       NaN       NaN              NaN
# 14        NaN       NaN       NaN       NaN              NaN
# 15        NaN       NaN       NaN       NaN              NaN
# 16        NaN       NaN       NaN       NaN              NaN
# 17        NaN       NaN       NaN       NaN              NaN
# 18        NaN       NaN       NaN       NaN              NaN
# 19        NaN       NaN       NaN       NaN              NaN
# 30       0.25  0.386667  0.303333  0.193333            0.733
# 31       0.25  0.386667  0.303333  0.193333            0.733
# 32       0.25  0.386667  0.303333  0.193333            0.733
# 33       0.25  0.386667  0.303333  0.193333            0.733
# 34       0.25  0.386667  0.303333  0.193333            0.733
# 35       0.25  0.386667  0.303333  0.193333            0.733
# 36       0.25  0.386667  0.303333  0.193333            0.733
# 37       0.25  0.386667  0.303333  0.193333            0.733
# 38       0.25  0.386667  0.303333  0.193333            0.733
# 39       0.25  0.386667  0.303333  0.193333            0.733

# %%
filtered_df_tap = df_tap[df_tap["Method"] == "SPH+CPI"]

best_run_df['Acc average'] = best_run_df.groupby(['Run','gini', 'p value', 'Method'])['A@e'].transform('mean')
idx = best_run_df.groupby(['gini', 'p value'])['Acc average'].transform(max) == best_run_df['Acc average']
print(idx)
print(best_run_df[idx])
#df_max_acc = df_tap[ (df_tap["Acc average"] == df_tap["Acc average"].max()) & ]
#sns.lineplot(x="R_e", y="A@e", data=df_max_acc, hue='Method')
# Out:
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
#         ...
# 1330     True
# 1340     True
# 1350     True
# 2180     True
# 3110    False
# Name: Acc average, Length: 260, dtype: bool
#       R_e       A@e   Method  gini  p value  Run  SPH Executed  info loss  \
# 1       2  0.493333      SPH -1.00    -1.00  1.0           8.0       0.25
# 2       3  0.573333      SPH -1.00    -1.00  1.0           8.0       0.25
# 3       4  0.636667      SPH -1.00    -1.00  1.0           8.0       0.25
# 4       5  0.713333      SPH -1.00    -1.00  1.0           8.0       0.25
# 5       6  0.740000      SPH -1.00    -1.00  1.0           8.0       0.25
# ...   ...       ...      ...   ...      ...  ...           ...        ...
# 1320    1  0.353333  SPH+CPI  0.35     0.70  1.0           8.0       0.25
# 1330    1  0.353333  SPH+CPI  0.35     0.75  1.0           8.0       0.25
# 1340    1  0.353333  SPH+CPI  0.40     0.70  1.0           8.0       0.25
# 1350    1  0.353333  SPH+CPI  0.40     0.75  1.0           8.0       0.25
# 2180    1  0.333333      SPH -1.00    -1.00  1.0           8.0       0.25
#
#        SPH A@1  RF+B A@1   CPI A@1  Acc average
# 1          NaN       NaN       NaN     0.659000
# 2          NaN       NaN       NaN     0.659000
# 3          NaN       NaN       NaN     0.659000
# 4          NaN       NaN       NaN     0.659000
# 5          NaN       NaN       NaN     0.659000
# ...        ...       ...       ...          ...
# 1320  0.333333  0.283333  0.276667     0.660333
# 1330  0.333333  0.283333  0.286667     0.660333
# 1340  0.333333  0.283333  0.276667     0.658333
# 1350  0.333333  0.283333  0.286667     0.658333
# 2180       NaN       NaN       NaN     0.659000
#
# [250 rows x 12 columns]
# <ipython-input-100-e312a70101a1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_run_df['Acc average'] = best_run_df.groupby(['Run','gini', 'p value', 'Method'])['A@e'].transform('mean')

# %%
#max_run = 10
#df_max_acc = df_max_acc.reset_index()
df_max_acc = best_run_df[best_run_df['Run'] == 1].
df_max_acc
# Out:
#       R_e       A@e   Method  gini  p value  Run  SPH Executed  info loss  \
# 1       2  0.493333      SPH -1.00    -1.00  1.0           8.0       0.25
# 2       3  0.573333      SPH -1.00    -1.00  1.0           8.0       0.25
# 3       4  0.636667      SPH -1.00    -1.00  1.0           8.0       0.25
# 4       5  0.713333      SPH -1.00    -1.00  1.0           8.0       0.25
# 5       6  0.740000      SPH -1.00    -1.00  1.0           8.0       0.25
# ...   ...       ...      ...   ...      ...  ...           ...        ...
# 1330    1  0.353333  SPH+CPI  0.35     0.75  1.0           8.0       0.25
# 1340    1  0.353333  SPH+CPI  0.40     0.70  1.0           8.0       0.25
# 1350    1  0.353333  SPH+CPI  0.40     0.75  1.0           8.0       0.25
# 2180    1  0.333333      SPH -1.00    -1.00  1.0           8.0       0.25
# 3110    1  0.283333     RF+B -1.00    -1.00  1.0           8.0        NaN
#
#        SPH A@1  RF+B A@1   CPI A@1  Acc average
# 1          NaN       NaN       NaN     0.659000
# 2          NaN       NaN       NaN     0.659000
# 3          NaN       NaN       NaN     0.659000
# 4          NaN       NaN       NaN     0.659000
# 5          NaN       NaN       NaN     0.659000
# ...        ...       ...       ...          ...
# 1330  0.333333  0.283333  0.286667     0.660333
# 1340  0.333333  0.283333  0.276667     0.658333
# 1350  0.333333  0.283333  0.286667     0.658333
# 2180       NaN       NaN       NaN     0.659000
# 3110       NaN       NaN       NaN     0.613000
#
# [260 rows x 12 columns]

# %%
df = pd.read_csv("acc_per_group.csv", sep=';', decimal=',')
df
# Out:
#      target  equal  train count   Method
# 0         0    0.0            2  SPH+CPI
# 1         1    0.0            1  SPH+CPI
# 2         2    1.0            2  SPH+CPI
# 3         3    0.0            1  SPH+CPI
# 4         4    0.0            2  SPH+CPI
# ..      ...    ...          ...      ...
# 139      79    0.0            3      CPI
# 140      80    0.0            3      CPI
# 141      81    0.0            3      CPI
# 142      82    0.0            3      CPI
# 143      83    0.0            3      CPI
#
# [144 rows x 4 columns]

# %%
df = df.drop(['Unnamed: 0.1', 'Unnamed: 0.1.1', 'Unnamed: 0.1.1.1'], axis='columns')

# %%
#df = df.drop([";group;target;equal;count;Method;\";group;target;equal;count;Method\""], axis='columns')
df
# Out:
#       Unnamed: 0      group  target     equal  count   Method
# 0              0  hde-OM1-2     1.0  0.000000    1.0  SPH+CPI
# 1              1  hde-OM1-2     2.0  1.000000    1.0  SPH+CPI
# 2              2  hde-OM1-2     3.0  0.000000    1.0  SPH+CPI
# 3              3  hde-OM1-2     4.0  0.000000    1.0  SPH+CPI
# 4              4  hde-OM1-3     5.0  0.333333    3.0  SPH+CPI
# ...          ...        ...     ...       ...    ...      ...
# 1102         979        NaN     NaN       NaN    NaN      NaN
# 1103         980        NaN     NaN       NaN    NaN      NaN
# 1104         981        NaN     NaN       NaN    NaN      NaN
# 1105         982        NaN     NaN       NaN    NaN      NaN
# 1106         983        NaN     NaN       NaN    NaN      NaN
#
# [1107 rows x 6 columns]

# %%
df = df.dropna()

# %%
df['target'].unique()
minority_df = df[df['train count'] < 16]
majority_df = df[df['train count']>=16]
print(minority_df["train count"].unique())
# Out:
# [ 2  1 10  7  5  4  3  6 15 12  9 13  8 11]

# %%
majority_df['accuracy'] = majority_df['equal'] 
df['accuracy'] = df['equal'] 
sns.barplot( palette="deep", data=majority_df, hue="Method", x="train count", y="accuracy", 
           # showmeans=True
           )
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# <ipython-input-66-7a594376ac9d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   majority_df['accuracy'] = majority_df['equal']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-7a594376ac9d> in <module>
#       1 majority_df['accuracy'] = majority_df['equal']
#       2 df['accuracy'] = df['equal']
# ----> 3 sns.barplot( palette="deep", data=majority_df, hue="Method", x="train count", y="accuracy", showmeans=True)
#       4 plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3150         ax = plt.gca()
#    3151
# -> 3152     plotter.plot(ax, kwargs)
#    3153     return ax
#    3154
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, bar_kws)
#    1655     def plot(self, ax, bar_kws):
#    1656         """Make the plot."""
# -> 1657         self.draw_bars(ax, bar_kws)
#    1658         self.annotate_axes(ax)
#    1659         if self.orient == "h":
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in draw_bars(self, ax, kws)
#    1638                 # Draw the bars
#    1639                 offpos = barpos + self.hue_offsets[j]
# -> 1640                 barfunc(offpos, self.statistic[:, j], self.nested_width,
#    1641                         color=self.colors[j], align="center",
#    1642                         label=hue_level, **kws)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2396                 label='_nolegend_',
#    2397                 )
# -> 2398             r.update(kwargs)
#    2399             r.get_path()._interpolation_steps = 100
#    2400             if orientation == 'vertical':
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     999                 func = getattr(self, 'set_' + k, None)
#    1000                 if not callable(func):
# -> 1001                     raise AttributeError('{!r} object has no property {!r}'
#    1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#
# AttributeError: 'Rectangle' object has no property 'showmeans'

# %%
minority_df['accuracy'] = minority_df['equal'] 
minority_df['class count'] = minority_df['count']
print(minority_df["train count"].unique())
sns.boxplot(palette="deep", data=minority_df, hue="Method", x="train count", y="accuracy", showmeans=True)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# <ipython-input-50-c6bc5a88b295>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   minority_df['accuracy'] = minority_df['equal']
# <ipython-input-50-c6bc5a88b295>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   minority_df['class count'] = minority_df['count']
# [ 1  2 10  7  4  3  6  5 12  9 13 15  8 11]

# %%
len(majority_df[majority_df['count']==8])
print(len(df))
sns.countplot(x="train count", data=df)
# Out:
# 615

# %%
print(sum(minority_df[minority_df["Method"] == "SPH+CPI"]['count']))
sns.countplot(x="class count", data=minority_df[minority_df["Method"] == "SPH+CPI"])
# Out:
# 264
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-5541e8412401> in <module>
#       1 print(sum(minority_df[minority_df["Method"] == "SPH+CPI"]['count']))
# ----> 2 sns.countplot(x="class count", data=minority_df[minority_df["Method"] == "SPH+CPI"])
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3547         raise TypeError("Must pass values for either `x` or `y`")
#    3548
# -> 3549     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3550                           estimator, ci, n_boot, units, seed,
#    3551                           orient, color, palette, saturation,
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1600                  errwidth, capsize, dodge):
#    1601         """Initialize the plotter."""
# -> 1602         self.establish_variables(x, y, hue, data, orient,
#    1603                                  order, hue_order, units)
#    1604         self.establish_colors(color, palette, saturation)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     150                 if isinstance(var, str):
#     151                     err = "Could not interpret input '{}'".format(var)
# --> 152                     raise ValueError(err)
#     153
#     154             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'class count'
