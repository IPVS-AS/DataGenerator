# %%
import pandas as pd
import os
import seaborn as sns

# %%
features_df = pd.read_csv("features/imbalance_degree/normal/result/gini_accuracy_all_runs.csv")
features_df = features_df[(features_df["Method"].isin(["RF+B","SPH", "SPH+CPI", "CPI"]))]
features_df["Method"] = pd.Categorical(features_df["Method"], ['RF+B','SPH', 'SPH+CPI', 'CPI'], ordered=True)
#features_df["Method"] = pd.Categorical(features_df["Method"], ['RF+B','SPH', 'SPH+CPI', 'CPI', 'KMeans', 'GMM', 'Birch','RF'], ordered=True)

# %%
# Out:
#       Method  R_e       A@e      RA@e  Run  max info loss     n    f   mf  \
# 20       SPH    1  0.283333  1.000000    1            0.1  1050  100  0.0
# 21       SPH    2  0.453333  1.375000    1            0.1  1050  100  0.0
# 22       SPH    3  0.556667  1.676647    1            0.1  1050  100  0.0
# 23       SPH    4  0.636667  1.968586    1            0.1  1050  100  0.0
# 24       SPH    5  0.693333  2.216346    1            0.1  1050  100  0.0
# ...      ...  ...       ...       ...  ...            ...   ...  ...  ...
# 11965    CPI    6  0.616667  2.610811    1            NaN  1050  100  0.4
# 11966    CPI    7  0.646667  2.814433    1            NaN  1050  100  0.4
# 11967    CPI    8  0.663333  2.944724    1            NaN  1050  100  0.4
# 11968    CPI    9  0.683333  3.121951    1            NaN  1050  100  0.4
# 11969    CPI   10  0.706667  3.349057    1            NaN  1050  100  0.4
#
#        n_clusters algorithm  n_components  gini  p value
# 20            NaN       NaN           NaN   NaN      NaN
# 21            NaN       NaN           NaN   NaN      NaN
# 22            NaN       NaN           NaN   NaN      NaN
# 23            NaN       NaN           NaN   NaN      NaN
# 24            NaN       NaN           NaN   NaN      NaN
# ...           ...       ...           ...   ...      ...
# 11965         NaN       NaN           NaN   0.4      0.9
# 11966         NaN       NaN           NaN   0.4      0.9
# 11967         NaN       NaN           NaN   0.4      0.9
# 11968         NaN       NaN           NaN   0.4      0.9
# 11969         NaN       NaN           NaN   0.4      0.9
#
# [10370 rows x 14 columns]

# %%
sns.relplot(data=features_df, x="R_e", y="A@e", hue="Method", row="f", kind="line")

# %%
parameters = ["max info loss", "gini", "p value", "n_clusters"]
methods_to_parameters = {
    "SPH+CPI": ["max info loss", "gini", "p value"],
    "SPH": ["max info loss"],
    "KMeans": ["n_clusters"],
    "Birch": ["n_clusters"],
    "GMM": ["n_clusters"],
    "CPI": ["gini", "p value"],
    "RF": [],
    "RF+B": []
}

# %%
best_result_df = pd.DataFrame()
for n in features_df["f"].unique():
    n_features_df = features_df[features_df["f"] == n]
    # find best parameter for each method
    for method in n_features_df["Method"].unique():
        method_df = n_features_df[n_features_df["Method"] == method]
        #print(method_df)
        first_position_df = method_df[(method_df["R_e"] == 1)]
        best_method_result = first_position_df[first_position_df["A@e"] == first_position_df["A@e"].max()]
        for parameter in methods_to_parameters[method]:
            parameter_value = best_method_result[parameter].values[0]
            if not parameter_value:
                continue
            method_df = method_df[method_df[parameter] == parameter_value]
        print(method_df)
        best_result_df = pd.concat([best_result_df, method_df])
best_result_df
# Out:
#    Method  R_e       A@e      RA@e  Run     n   f  max info loss  n_clusters  \
# 60    SPH    1  0.426667  1.000000    1  1050  50           0.35         NaN
# 61    SPH    2  0.616667  1.308108    1  1050  50           0.35         NaN
# 62    SPH    3  0.690000  1.487923    1  1050  50           0.35         NaN
# 63    SPH    4  0.733333  1.636364    1  1050  50           0.35         NaN
# 64    SPH    5  0.776667  1.824034    1  1050  50           0.35         NaN
# 65    SPH    6  0.786667  1.877119    1  1050  50           0.35         NaN
# 66    SPH    7  0.793333  1.920168    1  1050  50           0.35         NaN
# 67    SPH    8  0.803333  1.995851    1  1050  50           0.35         NaN
# 68    SPH    9  0.813333  2.081967    1  1050  50           0.35         NaN
# 69    SPH   10  0.816667  2.114286    1  1050  50           0.35         NaN
#
#    algorithm  n_components  gini  p value
# 60       NaN           NaN   NaN      NaN
# 61       NaN           NaN   NaN      NaN
# 62       NaN           NaN   NaN      NaN
# 63       NaN           NaN   NaN      NaN
# 64       NaN           NaN   NaN      NaN
# 65       NaN           NaN   NaN      NaN
# 66       NaN           NaN   NaN      NaN
# 67       NaN           NaN   NaN      NaN
# 68       NaN           NaN   NaN      NaN
# 69       NaN           NaN   NaN      NaN
#    Method  R_e       A@e      RA@e  Run     n   f  max info loss  n_clusters  \
# 80   RF+B    1  0.376667  1.000000    1  1050  50            NaN         NaN
# 81   RF+B    2  0.523333  1.280255    1  1050  50            NaN         NaN
# 82   RF+B    3  0.623333  1.556150    1  1050  50            NaN         NaN
# 83   RF+B    4  0.663333  1.703518    1  1050  50            NaN         NaN
# 84   RF+B    5  0.693333  1.846154    1  1050  50            NaN         NaN
# 85   RF+B    6  0.720000  2.000000    1  1050  50            NaN         NaN
# 86   RF+B    7  0.743333  2.156951    1  1050  50            NaN         NaN
# 87   RF+B    8  0.763333  2.310044    1  1050  50            NaN         NaN
# 88   RF+B    9  0.786667  2.508475    1  1050  50            NaN         NaN
# 89   RF+B   10  0.796667  2.602510    1  1050  50            NaN         NaN
#
#    algorithm  n_components  gini  p value
# 80       NaN           NaN   NaN      NaN
# 81       NaN           NaN   NaN      NaN
# 82       NaN           NaN   NaN      NaN
# 83       NaN           NaN   NaN      NaN
# 84       NaN           NaN   NaN      NaN
# 85       NaN           NaN   NaN      NaN
# 86       NaN           NaN   NaN      NaN
# 87       NaN           NaN   NaN      NaN
# 88       NaN           NaN   NaN      NaN
# 89       NaN           NaN   NaN      NaN
#        Method  R_e       A@e      RA@e  Run     n   f  max info loss  \
# 1840  SPH+CPI    1  0.433333  1.000000    1  1050  50           0.35
# 1841  SPH+CPI    2  0.593333  1.269663    1  1050  50           0.35
# 1842  SPH+CPI    3  0.676667  1.482759    1  1050  50           0.35
# 1843  SPH+CPI    4  0.730000  1.666667    1  1050  50           0.35
# 1844  SPH+CPI    5  0.770000  1.839827    1  1050  50           0.35
# 1845  SPH+CPI    6  0.776667  1.875536    1  1050  50           0.35
# 1846  SPH+CPI    7  0.786667  1.940678    1  1050  50           0.35
# 1847  SPH+CPI    8  0.800000  2.041667    1  1050  50           0.35
# 1848  SPH+CPI    9  0.806667  2.099174    1  1050  50           0.35
# 1849  SPH+CPI   10  0.810000  2.131687    1  1050  50           0.35
#
#       n_clusters algorithm  n_components  gini  p value
# 1840         NaN       NaN           NaN   0.4      0.7
# 1841         NaN       NaN           NaN   0.4      0.7
# 1842         NaN       NaN           NaN   0.4      0.7
# 1843         NaN       NaN           NaN   0.4      0.7
# 1844         NaN       NaN           NaN   0.4      0.7
# 1845         NaN       NaN           NaN   0.4      0.7
# 1846         NaN       NaN           NaN   0.4      0.7
# 1847         NaN       NaN           NaN   0.4      0.7
# 1848         NaN       NaN           NaN   0.4      0.7
# 1849         NaN       NaN           NaN   0.4      0.7
#      Method  R_e       A@e      RA@e  Run     n   f  max info loss  \
# 2140    CPI    1  0.376667  1.000000    1  1050  50            NaN
# 2141    CPI    2  0.490000  1.231293    1  1050  50            NaN
# 2142    CPI    3  0.550000  1.424242    1  1050  50            NaN
# 2143    CPI    4  0.593333  1.612360    1  1050  50            NaN
# 2144    CPI    5  0.623333  1.775401    1  1050  50            NaN
# 2145    CPI    6  0.660000  2.010101    1  1050  50            NaN
# 2146    CPI    7  0.690000  2.227053    1  1050  50            NaN
# 2147    CPI    8  0.716667  2.441860    1  1050  50            NaN
# 2148    CPI    9  0.733333  2.590909    1  1050  50            NaN
# 2149    CPI   10  0.753333  2.787611    1  1050  50            NaN
#
#       n_clusters algorithm  n_components  gini  p value
# 2140         NaN       NaN           NaN   0.2      0.7
# 2141         NaN       NaN           NaN   0.2      0.7
# 2142         NaN       NaN           NaN   0.2      0.7
# 2143         NaN       NaN           NaN   0.2      0.7
# 2144         NaN       NaN           NaN   0.2      0.7
# 2145         NaN       NaN           NaN   0.2      0.7
# 2146         NaN       NaN           NaN   0.2      0.7
# 2147         NaN       NaN           NaN   0.2      0.7
# 2148         NaN       NaN           NaN   0.2      0.7
# 2149         NaN       NaN           NaN   0.2      0.7
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 2449    SPH    1  0.316667  1.000000    1  1050  100           0.35
# 2450    SPH    2  0.516667  1.387097    1  1050  100           0.35
# 2451    SPH    3  0.613333  1.641304    1  1050  100           0.35
# 2452    SPH    4  0.680000  1.872549    1  1050  100           0.35
# 2453    SPH    5  0.730000  2.086758    1  1050  100           0.35
# 2454    SPH    6  0.760000  2.241228    1  1050  100           0.35
# 2455    SPH    7  0.780000  2.363248    1  1050  100           0.35
# 2456    SPH    8  0.793333  2.457983    1  1050  100           0.35
# 2457    SPH    9  0.806667  2.566116    1  1050  100           0.35
#
#       n_clusters algorithm  n_components  gini  p value
# 2449         NaN       NaN           NaN   NaN      NaN
# 2450         NaN       NaN           NaN   NaN      NaN
# 2451         NaN       NaN           NaN   NaN      NaN
# 2452         NaN       NaN           NaN   NaN      NaN
# 2453         NaN       NaN           NaN   NaN      NaN
# 2454         NaN       NaN           NaN   NaN      NaN
# 2455         NaN       NaN           NaN   NaN      NaN
# 2456         NaN       NaN           NaN   NaN      NaN
# 2457         NaN       NaN           NaN   NaN      NaN
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 2467   RF+B    1  0.300000  1.000000    1  1050  100            NaN
# 2468   RF+B    2  0.453333  1.338235    1  1050  100            NaN
# 2469   RF+B    3  0.550000  1.630303    1  1050  100            NaN
# 2470   RF+B    4  0.630000  1.931217    1  1050  100            NaN
# 2471   RF+B    5  0.656667  2.055838    1  1050  100            NaN
# 2472   RF+B    6  0.690000  2.246377    1  1050  100            NaN
# 2473   RF+B    7  0.713333  2.401869    1  1050  100            NaN
# 2474   RF+B    8  0.726667  2.504587    1  1050  100            NaN
# 2475   RF+B    9  0.746667  2.678571    1  1050  100            NaN
# 2476   RF+B   10  0.760000  2.807018    1  1050  100            NaN
#
#       n_clusters algorithm  n_components  gini  p value
# 2467         NaN       NaN           NaN   NaN      NaN
# 2468         NaN       NaN           NaN   NaN      NaN
# 2469         NaN       NaN           NaN   NaN      NaN
# 2470         NaN       NaN           NaN   NaN      NaN
# 2471         NaN       NaN           NaN   NaN      NaN
# 2472         NaN       NaN           NaN   NaN      NaN
# 2473         NaN       NaN           NaN   NaN      NaN
# 2474         NaN       NaN           NaN   NaN      NaN
# 2475         NaN       NaN           NaN   NaN      NaN
# 2476         NaN       NaN           NaN   NaN      NaN
#        Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 4017  SPH+CPI    1  0.336667  1.000000    1  1050  100            0.3
# 4018  SPH+CPI    2  0.516667  1.348387    1  1050  100            0.3
# 4019  SPH+CPI    3  0.606667  1.593407    1  1050  100            0.3
# 4020  SPH+CPI    4  0.670000  1.820896    1  1050  100            0.3
# 4021  SPH+CPI    5  0.723333  2.055300    1  1050  100            0.3
# 4022  SPH+CPI    6  0.756667  2.229075    1  1050  100            0.3
# 4023  SPH+CPI    7  0.780000  2.371795    1  1050  100            0.3
# 4024  SPH+CPI    8  0.786667  2.419492    1  1050  100            0.3
# 4025  SPH+CPI    9  0.810000  2.609053    1  1050  100            0.3
#
#       n_clusters algorithm  n_components  gini  p value
# 4017         NaN       NaN           NaN   0.4      0.9
# 4018         NaN       NaN           NaN   0.4      0.9
# 4019         NaN       NaN           NaN   0.4      0.9
# 4020         NaN       NaN           NaN   0.4      0.9
# 4021         NaN       NaN           NaN   0.4      0.9
# 4022         NaN       NaN           NaN   0.4      0.9
# 4023         NaN       NaN           NaN   0.4      0.9
# 4024         NaN       NaN           NaN   0.4      0.9
# 4025         NaN       NaN           NaN   0.4      0.9
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 4524    CPI    1  0.296667  1.000000    1  1050  100            NaN
# 4525    CPI    2  0.450000  1.340741    1  1050  100            NaN
# 4526    CPI    3  0.540000  1.617284    1  1050  100            NaN
# 4527    CPI    4  0.610000  1.890710    1  1050  100            NaN
# 4528    CPI    5  0.650000  2.082051    1  1050  100            NaN
# 4529    CPI    6  0.683333  2.273171    1  1050  100            NaN
# 4530    CPI    7  0.706667  2.429245    1  1050  100            NaN
# 4531    CPI    8  0.733333  2.631818    1  1050  100            NaN
# 4532    CPI    9  0.773333  2.961207    1  1050  100            NaN
# 4533    CPI   10  0.793333  3.138655    1  1050  100            NaN
#
#       n_clusters algorithm  n_components  gini  p value
# 4524         NaN       NaN           NaN   0.2      0.7
# 4525         NaN       NaN           NaN   0.2      0.7
# 4526         NaN       NaN           NaN   0.2      0.7
# 4527         NaN       NaN           NaN   0.2      0.7
# 4528         NaN       NaN           NaN   0.2      0.7
# 4529         NaN       NaN           NaN   0.2      0.7
# 4530         NaN       NaN           NaN   0.2      0.7
# 4531         NaN       NaN           NaN   0.2      0.7
# 4532         NaN       NaN           NaN   0.2      0.7
# 4533         NaN       NaN           NaN   0.2      0.7
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 4834    SPH    1  0.360000  1.000000    1  1050  250           0.35
# 4835    SPH    2  0.503333  1.284768    1  1050  250           0.35
# 4836    SPH    3  0.623333  1.614973    1  1050  250           0.35
# 4837    SPH    4  0.693333  1.855769    1  1050  250           0.35
# 4838    SPH    5  0.743333  2.067265    1  1050  250           0.35
# 4839    SPH    6  0.770000  2.203463    1  1050  250           0.35
# 4840    SPH    7  0.783333  2.285106    1  1050  250           0.35
# 4841    SPH    8  0.803333  2.427386    1  1050  250           0.35
# 4842    SPH    9  0.820000  2.560976    1  1050  250           0.35
# 4843    SPH   10  0.833333  2.680000    1  1050  250           0.35
#
#       n_clusters algorithm  n_components  gini  p value
# 4834         NaN       NaN           NaN   NaN      NaN
# 4835         NaN       NaN           NaN   NaN      NaN
# 4836         NaN       NaN           NaN   NaN      NaN
# 4837         NaN       NaN           NaN   NaN      NaN
# 4838         NaN       NaN           NaN   NaN      NaN
# 4839         NaN       NaN           NaN   NaN      NaN
# 4840         NaN       NaN           NaN   NaN      NaN
# 4841         NaN       NaN           NaN   NaN      NaN
# 4842         NaN       NaN           NaN   NaN      NaN
# 4843         NaN       NaN           NaN   NaN      NaN
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 4854   RF+B    1  0.310000  1.000000    1  1050  250            NaN
# 4855   RF+B    2  0.400000  1.225000    1  1050  250            NaN
# 4856   RF+B    3  0.500000  1.580000    1  1050  250            NaN
# 4857   RF+B    4  0.583333  1.925714    1  1050  250            NaN
# 4858   RF+B    5  0.630000  2.153439    1  1050  250            NaN
# 4859   RF+B    6  0.663333  2.346734    1  1050  250            NaN
# 4860   RF+B    7  0.690000  2.526570    1  1050  250            NaN
# 4861   RF+B    8  0.723333  2.778802    1  1050  250            NaN
# 4862   RF+B    9  0.740000  2.918919    1  1050  250            NaN
# 4863   RF+B   10  0.763333  3.135371    1  1050  250            NaN
#
#       n_clusters algorithm  n_components  gini  p value
# 4854         NaN       NaN           NaN   NaN      NaN
# 4855         NaN       NaN           NaN   NaN      NaN
# 4856         NaN       NaN           NaN   NaN      NaN
# 4857         NaN       NaN           NaN   NaN      NaN
# 4858         NaN       NaN           NaN   NaN      NaN
# 4859         NaN       NaN           NaN   NaN      NaN
# 4860         NaN       NaN           NaN   NaN      NaN
# 4861         NaN       NaN           NaN   NaN      NaN
# 4862         NaN       NaN           NaN   NaN      NaN
# 4863         NaN       NaN           NaN   NaN      NaN
#        Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 6318  SPH+CPI    1  0.363333  1.000000    1  1050  250            0.3
# 6319  SPH+CPI    2  0.506667  1.282895    1  1050  250            0.3
# 6320  SPH+CPI    3  0.623333  1.604278    1  1050  250            0.3
# 6321  SPH+CPI    4  0.706667  1.886792    1  1050  250            0.3
# 6322  SPH+CPI    5  0.753333  2.079646    1  1050  250            0.3
# 6323  SPH+CPI    6  0.780000  2.213675    1  1050  250            0.3
# 6324  SPH+CPI    7  0.790000  2.274262    1  1050  250            0.3
# 6325  SPH+CPI    8  0.806667  2.392562    1  1050  250            0.3
# 6326  SPH+CPI    9  0.826667  2.552419    1  1050  250            0.3
# 6327  SPH+CPI   10  0.830000  2.582329    1  1050  250            0.3
#
#       n_clusters algorithm  n_components  gini  p value
# 6318         NaN       NaN           NaN  0.35     0.75
# 6319         NaN       NaN           NaN  0.35     0.75
# 6320         NaN       NaN           NaN  0.35     0.75
# 6321         NaN       NaN           NaN  0.35     0.75
# 6322         NaN       NaN           NaN  0.35     0.75
# 6323         NaN       NaN           NaN  0.35     0.75
# 6324         NaN       NaN           NaN  0.35     0.75
# 6325         NaN       NaN           NaN  0.35     0.75
# 6326         NaN       NaN           NaN  0.35     0.75
# 6327         NaN       NaN           NaN  0.35     0.75
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 6908    CPI    1  0.270000  1.000000    1  1050  250            NaN
# 6909    CPI    2  0.373333  1.276786    1  1050  250            NaN
# 6910    CPI    3  0.486667  1.678082    1  1050  250            NaN
# 6911    CPI    4  0.540000  1.907407    1  1050  250            NaN
# 6912    CPI    5  0.606667  2.247253    1  1050  250            NaN
# 6913    CPI    6  0.643333  2.461140    1  1050  250            NaN
# 6914    CPI    7  0.663333  2.597990    1  1050  250            NaN
# 6915    CPI    8  0.696667  2.856459    1  1050  250            NaN
# 6916    CPI    9  0.703333  2.914692    1  1050  250            NaN
# 6917    CPI   10  0.713333  3.014019    1  1050  250            NaN
#
#       n_clusters algorithm  n_components  gini  p value
# 6908         NaN       NaN           NaN   0.2      0.7
# 6909         NaN       NaN           NaN   0.2      0.7
# 6910         NaN       NaN           NaN   0.2      0.7
# 6911         NaN       NaN           NaN   0.2      0.7
# 6912         NaN       NaN           NaN   0.2      0.7
# 6913         NaN       NaN           NaN   0.2      0.7
# 6914         NaN       NaN           NaN   0.2      0.7
# 6915         NaN       NaN           NaN   0.2      0.7
# 6916         NaN       NaN           NaN   0.2      0.7
# 6917         NaN       NaN           NaN   0.2      0.7
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 7208    SPH    1  0.336667  1.000000    1  1050  500            0.3
# 7209    SPH    2  0.480000  1.298611    1  1050  500            0.3
# 7210    SPH    3  0.596667  1.631285    1  1050  500            0.3
# 7211    SPH    4  0.706667  2.000000    1  1050  500            0.3
# 7212    SPH    5  0.770000  2.246753    1  1050  500            0.3
# 7213    SPH    6  0.773333  2.262931    1  1050  500            0.3
# 7214    SPH    7  0.793333  2.382353    1  1050  500            0.3
# 7215    SPH    8  0.816667  2.542857    1  1050  500            0.3
# 7216    SPH    9  0.823333  2.595142    1  1050  500            0.3
# 7217    SPH   10  0.830000  2.654618    1  1050  500            0.3
#
#       n_clusters algorithm  n_components  gini  p value
# 7208         NaN       NaN           NaN   NaN      NaN
# 7209         NaN       NaN           NaN   NaN      NaN
# 7210         NaN       NaN           NaN   NaN      NaN
# 7211         NaN       NaN           NaN   NaN      NaN
# 7212         NaN       NaN           NaN   NaN      NaN
# 7213         NaN       NaN           NaN   NaN      NaN
# 7214         NaN       NaN           NaN   NaN      NaN
# 7215         NaN       NaN           NaN   NaN      NaN
# 7216         NaN       NaN           NaN   NaN      NaN
# 7217         NaN       NaN           NaN   NaN      NaN
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 7238   RF+B    1  0.230000  1.000000    1  1050  500            NaN
# 7239   RF+B    2  0.400000  1.425000    1  1050  500            NaN
# 7240   RF+B    3  0.480000  1.687500    1  1050  500            NaN
# 7241   RF+B    4  0.580000  2.086207    1  1050  500            NaN
# 7242   RF+B    5  0.660000  2.439394    1  1050  500            NaN
# 7243   RF+B    6  0.700000  2.642857    1  1050  500            NaN
# 7244   RF+B    7  0.736667  2.859729    1  1050  500            NaN
# 7245   RF+B    8  0.753333  2.973451    1  1050  500            NaN
# 7246   RF+B    9  0.760000  3.026316    1  1050  500            NaN
# 7247   RF+B   10  0.770000  3.116883    1  1050  500            NaN
#
#       n_clusters algorithm  n_components  gini  p value
# 7238         NaN       NaN           NaN   NaN      NaN
# 7239         NaN       NaN           NaN   NaN      NaN
# 7240         NaN       NaN           NaN   NaN      NaN
# 7241         NaN       NaN           NaN   NaN      NaN
# 7242         NaN       NaN           NaN   NaN      NaN
# 7243         NaN       NaN           NaN   NaN      NaN
# 7244         NaN       NaN           NaN   NaN      NaN
# 7245         NaN       NaN           NaN   NaN      NaN
# 7246         NaN       NaN           NaN   NaN      NaN
# 7247         NaN       NaN           NaN   NaN      NaN
#        Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 8706  SPH+CPI    1  0.340000  1.000000    1  1050  500            0.3
# 8707  SPH+CPI    2  0.480000  1.291667    1  1050  500            0.3
# 8708  SPH+CPI    3  0.570000  1.561404    1  1050  500            0.3
# 8709  SPH+CPI    4  0.673333  1.935644    1  1050  500            0.3
# 8710  SPH+CPI    5  0.763333  2.296943    1  1050  500            0.3
# 8711  SPH+CPI    6  0.770000  2.329004    1  1050  500            0.3
# 8712  SPH+CPI    7  0.790000  2.447257    1  1050  500            0.3
# 8713  SPH+CPI    8  0.813333  2.606557    1  1050  500            0.3
# 8714  SPH+CPI    9  0.823333  2.684211    1  1050  500            0.3
# 8715  SPH+CPI   10  0.833333  2.772000    1  1050  500            0.3
#
#       n_clusters algorithm  n_components  gini  p value
# 8706         NaN       NaN           NaN  0.35     0.75
# 8707         NaN       NaN           NaN  0.35     0.75
# 8708         NaN       NaN           NaN  0.35     0.75
# 8709         NaN       NaN           NaN  0.35     0.75
# 8710         NaN       NaN           NaN  0.35     0.75
# 8711         NaN       NaN           NaN  0.35     0.75
# 8712         NaN       NaN           NaN  0.35     0.75
# 8713         NaN       NaN           NaN  0.35     0.75
# 8714         NaN       NaN           NaN  0.35     0.75
# 8715         NaN       NaN           NaN  0.35     0.75
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 9304    CPI    1  0.253333  1.000000    1  1050  500            NaN
# 9305    CPI    2  0.356667  1.289720    1  1050  500            NaN
# 9306    CPI    3  0.433333  1.592308    1  1050  500            NaN
# 9307    CPI    4  0.490000  1.870748    1  1050  500            NaN
# 9308    CPI    5  0.546667  2.195122    1  1050  500            NaN
# 9309    CPI    6  0.573333  2.372093    1  1050  500            NaN
# 9310    CPI    7  0.610000  2.650273    1  1050  500            NaN
# 9311    CPI    8  0.636667  2.874346    1  1050  500            NaN
# 9312    CPI    9  0.653333  3.030612    1  1050  500            NaN
# 9313    CPI   10  0.673333  3.237624    1  1050  500            NaN
#
#       n_clusters algorithm  n_components  gini  p value
# 9304         NaN       NaN           NaN   0.2     0.75
# 9305         NaN       NaN           NaN   0.2     0.75
# 9306         NaN       NaN           NaN   0.2     0.75
# 9307         NaN       NaN           NaN   0.2     0.75
# 9308         NaN       NaN           NaN   0.2     0.75
# 9309         NaN       NaN           NaN   0.2     0.75
# 9310         NaN       NaN           NaN   0.2     0.75
# 9311         NaN       NaN           NaN   0.2     0.75
# 9312         NaN       NaN           NaN   0.2     0.75
# 9313         NaN       NaN           NaN   0.2     0.75
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 60      SPH    1  0.426667  1.000000    1  1050   50           0.35
# 61      SPH    2  0.616667  1.308108    1  1050   50           0.35
# 62      SPH    3  0.690000  1.487923    1  1050   50           0.35
# 63      SPH    4  0.733333  1.636364    1  1050   50           0.35
# 64      SPH    5  0.776667  1.824034    1  1050   50           0.35
# ...     ...  ...       ...       ...  ...   ...  ...            ...
# 9309    CPI    6  0.573333  2.372093    1  1050  500            NaN
# 9310    CPI    7  0.610000  2.650273    1  1050  500            NaN
# 9311    CPI    8  0.636667  2.874346    1  1050  500            NaN
# 9312    CPI    9  0.653333  3.030612    1  1050  500            NaN
# 9313    CPI   10  0.673333  3.237624    1  1050  500            NaN
#
#       n_clusters algorithm  n_components  gini  p value
# 60           NaN       NaN           NaN   NaN      NaN
# 61           NaN       NaN           NaN   NaN      NaN
# 62           NaN       NaN           NaN   NaN      NaN
# 63           NaN       NaN           NaN   NaN      NaN
# 64           NaN       NaN           NaN   NaN      NaN
# ...          ...       ...           ...   ...      ...
# 9309         NaN       NaN           NaN   0.2     0.75
# 9310         NaN       NaN           NaN   0.2     0.75
# 9311         NaN       NaN           NaN   0.2     0.75
# 9312         NaN       NaN           NaN   0.2     0.75
# 9313         NaN       NaN           NaN   0.2     0.75
#
# [158 rows x 13 columns]

# %%
ax = sns.relplot(data=best_result_df[best_result_df["Method"].isin(["SPH", "SPH+CPI", "RF", "CPI"])], x="R_e", y="A@e", style="Method", markers=True,hue="Method", col="f",facet_kws={'sharey': False, 'sharex': True}, kind="line", col_wrap=2)
ax.set(yticks=[x/20 for x in range(1, 20)])
#import matplotlib.pyplot as plt
#plt.ticklabel_format(axis='both', style='scientific', scilimits=(0, 0));

# %%
sns.relplot(data=best_result_df[best_result_df["Method"].isin(["SPH", "SPH+CPI", "RF", "KMeans", "Birch"])],style="Method", markers=True, x="R_e", y="A@e", hue="Method", col="f", kind="line", col_wrap=2)

# %%
best_parameter_df = pd.DataFrame()
for n in best_result_df["n"].unique():
    #print("--------------------------------------")
    #print(f"n={n}")
    best_n_samples = best_result_df[best_result_df["n"] == n]
    for method in best_n_samples["Method"].unique():
        param_df = best_n_samples[(best_n_samples["Method"] == method) & (best_n_samples["R_e"] == 1)][methods_to_parameters[method]]
        #print(f"Method {method} has best parameters:")
        #print(param_df)
        #print("--------------------------------------")
        param_df["Method"] = method
        param_df["n"] = n
        best_parameter_df = pd.concat([best_parameter_df, param_df])
    
best_parameter_df
# Out:
#        Method     n  max info loss  n_clusters  gini  p value
# 0          RF  1050            NaN         NaN   NaN      NaN
# 2390       RF  1050            NaN         NaN   NaN      NaN
# 4774       RF  1050            NaN         NaN   NaN      NaN
# 7158       RF  1050            NaN         NaN   NaN      NaN
# 60        SPH  1050           0.35         NaN   NaN      NaN
# 2449      SPH  1050           0.35         NaN   NaN      NaN
# 4834      SPH  1050           0.35         NaN   NaN      NaN
# 7218      SPH  1050           0.35         NaN   NaN      NaN
# 80       RF+B  1050            NaN         NaN   NaN      NaN
# 2467     RF+B  1050            NaN         NaN   NaN      NaN
# 4854     RF+B  1050            NaN         NaN   NaN      NaN
# 7238     RF+B  1050            NaN         NaN   NaN      NaN
# 130    KMeans  1050            NaN        26.0   NaN      NaN
# 2517   KMeans  1050            NaN        26.0   NaN      NaN
# 4904   KMeans  1050            NaN        26.0   NaN      NaN
# 7288   KMeans  1050            NaN        26.0   NaN      NaN
# 350     Birch  1050            NaN        35.0   NaN      NaN
# 2737    Birch  1050            NaN        35.0   NaN      NaN
# 5124    Birch  1050            NaN        35.0   NaN      NaN
# 7508    Birch  1050            NaN        35.0   NaN      NaN
# 1840  SPH+CPI  1050           0.35         NaN   0.4      0.7
# 4226  SPH+CPI  1050           0.35         NaN   0.4      0.7
# 6608  SPH+CPI  1050           0.35         NaN   0.4      0.7
# 8995  SPH+CPI  1050           0.35         NaN   0.4      0.7
# 2140      CPI  1050            NaN         NaN   0.2      0.7
# 4524      CPI  1050            NaN         NaN   0.2      0.7
# 6908      CPI  1050            NaN         NaN   0.2      0.7
# 9294      CPI  1050            NaN         NaN   0.2      0.7

# %%
ax = sns.barplot(hue="f", x="Method", y="A@e", data=best_result_df[(best_result_df["Method"].isin(["RF+B","SPH", "SPH+CPI", "CPI"])) & (best_result_df["R_e"] == 1)])
ax.legend(loc="upper right")
ax.set_ylabel("A@1 Accuracy")
# Out:
# Text(0, 0.5, 'A@1 Accuracy')
