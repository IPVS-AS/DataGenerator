# %%
import pandas as pd
import os
import seaborn as sns

# %%
flat_df = pd.read_csv("flat/imbalance_degree/normal/result/gini_accuracy_all_runs.csv")
flat_df["hierarchy"] = "flat"
samples_df = pd.read_csv("samples/imbalance_degree/normal/result/gini_accuracy_all_runs.csv")
samples_df = samples_df[samples_df["n"] == 1050]
samples_df["hierarchy"] = "normal"
flat_df = pd.concat([flat_df, samples_df])
flat_df
# Out:
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 0        RF    1  0.320000  1.000000    1  1050  100            NaN
# 1        RF    2  0.466667  1.314286    1  1050  100            NaN
# 2        RF    3  0.560000  1.595238    1  1050  100            NaN
# 3        RF    4  0.646667  1.917526    1  1050  100            NaN
# 4        RF    5  0.706667  2.179245    1  1050  100            NaN
# ...     ...  ...       ...       ...  ...   ...  ...            ...
# 4721    CPI    6  0.556667  2.377246    1  1050  100            NaN
# 4722    CPI    7  0.590000  2.638418    1  1050  100            NaN
# 4723    CPI    8  0.630000  2.978836    1  1050  100            NaN
# 4724    CPI    9  0.666667  3.310000    1  1050  100            NaN
# 4725    CPI   10  0.700000  3.628571    1  1050  100            NaN
#
#       n_clusters algorithm  n_components  gini  p value hierarchy
# 0            NaN       NaN           NaN   NaN      NaN      flat
# 1            NaN       NaN           NaN   NaN      NaN      flat
# 2            NaN       NaN           NaN   NaN      NaN      flat
# 3            NaN       NaN           NaN   NaN      NaN      flat
# 4            NaN       NaN           NaN   NaN      NaN      flat
# ...          ...       ...           ...   ...      ...       ...
# 4721         NaN       NaN           NaN   0.4      0.9    normal
# 4722         NaN       NaN           NaN   0.4      0.9    normal
# 4723         NaN       NaN           NaN   0.4      0.9    normal
# 4724         NaN       NaN           NaN   0.4      0.9    normal
# 4725         NaN       NaN           NaN   0.4      0.9    normal
#
# [4777 rows x 14 columns]

# %%
sns.relplot(data=flat_df, x="R_e", y="A@e", hue="Method", row="hierarchy", kind="line")

# %%
parameters = ["max info loss", "gini", "p value", "n_clusters"]
methods_to_parameters = {
    "SPH+CPI": ["max info loss", "gini", "p value"],
    "SPH": ["max info loss"],
    "KMeans": ["n_clusters"],
    "Birch": ["n_clusters"],
    "GMM": ["n_clusters"],
    "CPI": ["gini", "p value"],
    "RF": [],
    "RF+B": []
}

# %%
best_result_df = pd.DataFrame()
for n in flat_df["hierarchy"].unique():
    hierarchy_flat_df = flat_df[flat_df["hierarchy"] == n]
    # find best parameter for each method
    for method in hierarchy_flat_df["Method"].unique():
        method_df = hierarchy_flat_df[hierarchy_flat_df["Method"] == method]
        #print(method_df)
        first_position_df = method_df[(method_df["R_e"] == 1)]
        best_method_result = first_position_df[first_position_df["A@e"] == first_position_df["A@e"].max()]
        for parameter in methods_to_parameters[method]:
            parameter_value = best_method_result[parameter].values[0]
            if not parameter_value:
                continue
            method_df = method_df[method_df[parameter] == parameter_value]
        print(method_df)
        best_result_df = pd.concat([best_result_df, method_df])
best_result_df
# Out:
#   Method  R_e       A@e      RA@e  Run     n    f  max info loss  n_clusters  \
# 0     RF    1  0.320000  1.000000    1  1050  100            NaN         NaN
# 1     RF    2  0.466667  1.314286    1  1050  100            NaN         NaN
# 2     RF    3  0.560000  1.595238    1  1050  100            NaN         NaN
# 3     RF    4  0.646667  1.917526    1  1050  100            NaN         NaN
# 4     RF    5  0.706667  2.179245    1  1050  100            NaN         NaN
# 5     RF    6  0.723333  2.267281    1  1050  100            NaN         NaN
# 6     RF    7  0.740000  2.373874    1  1050  100            NaN         NaN
# 7     RF    8  0.746667  2.424107    1  1050  100            NaN         NaN
# 8     RF    9  0.773333  2.650862    1  1050  100            NaN         NaN
# 9     RF   10  0.786667  2.775424    1  1050  100            NaN         NaN
#
#   algorithm  n_components  gini  p value hierarchy
# 0       NaN           NaN   NaN      NaN      flat
# 1       NaN           NaN   NaN      NaN      flat
# 2       NaN           NaN   NaN      NaN      flat
# 3       NaN           NaN   NaN      NaN      flat
# 4       NaN           NaN   NaN      NaN      flat
# 5       NaN           NaN   NaN      NaN      flat
# 6       NaN           NaN   NaN      NaN      flat
# 7       NaN           NaN   NaN      NaN      flat
# 8       NaN           NaN   NaN      NaN      flat
# 9       NaN           NaN   NaN      NaN      flat
#    Method  R_e       A@e      RA@e  Run     n    f  max info loss  n_clusters  \
# 59    SPH    1  0.323333  1.000000    1  1050  100           0.35         NaN
# 60    SPH    2  0.516667  1.374194    1  1050  100           0.35         NaN
# 61    SPH    3  0.616667  1.637838    1  1050  100           0.35         NaN
# 62    SPH    4  0.686667  1.878641    1  1050  100           0.35         NaN
# 63    SPH    5  0.743333  2.116592    1  1050  100           0.35         NaN
# 64    SPH    6  0.770000  2.251082    1  1050  100           0.35         NaN
# 65    SPH    7  0.786667  2.351695    1  1050  100           0.35         NaN
# 66    SPH    8  0.803333  2.468880    1  1050  100           0.35         NaN
# 67    SPH    9  0.816667  2.575510    1  1050  100           0.35         NaN
#
#    algorithm  n_components  gini  p value hierarchy
# 59       NaN           NaN   NaN      NaN      flat
# 60       NaN           NaN   NaN      NaN      flat
# 61       NaN           NaN   NaN      NaN      flat
# 62       NaN           NaN   NaN      NaN      flat
# 63       NaN           NaN   NaN      NaN      flat
# 64       NaN           NaN   NaN      NaN      flat
# 65       NaN           NaN   NaN      NaN      flat
# 66       NaN           NaN   NaN      NaN      flat
# 67       NaN           NaN   NaN      NaN      flat
#    Method  R_e       A@e      RA@e  Run     n    f  max info loss  n_clusters  \
# 77   RF+B    1  0.263333  1.000000    1  1050  100            NaN         NaN
# 78   RF+B    2  0.450000  1.414815    1  1050  100            NaN         NaN
# 79   RF+B    3  0.546667  1.695122    1  1050  100            NaN         NaN
# 80   RF+B    4  0.590000  1.864407    1  1050  100            NaN         NaN
# 81   RF+B    5  0.646667  2.139175    1  1050  100            NaN         NaN
# 82   RF+B    6  0.680000  2.328431    1  1050  100            NaN         NaN
# 83   RF+B    7  0.713333  2.546729    1  1050  100            NaN         NaN
# 84   RF+B    8  0.743333  2.766816    1  1050  100            NaN         NaN
# 85   RF+B    9  0.766667  2.956522    1  1050  100            NaN         NaN
# 86   RF+B   10  0.776667  3.047210    1  1050  100            NaN         NaN
#
#    algorithm  n_components  gini  p value hierarchy
# 77       NaN           NaN   NaN      NaN      flat
# 78       NaN           NaN   NaN      NaN      flat
# 79       NaN           NaN   NaN      NaN      flat
# 80       NaN           NaN   NaN      NaN      flat
# 81       NaN           NaN   NaN      NaN      flat
# 82       NaN           NaN   NaN      NaN      flat
# 83       NaN           NaN   NaN      NaN      flat
# 84       NaN           NaN   NaN      NaN      flat
# 85       NaN           NaN   NaN      NaN      flat
# 86       NaN           NaN   NaN      NaN      flat
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 167  KMeans    1  0.370000  1.000000    1  1050  100            NaN
# 168  KMeans    2  0.533333  1.306250    1  1050  100            NaN
# 169  KMeans    3  0.623333  1.550802    1  1050  100            NaN
# 170  KMeans    4  0.690000  1.787440    1  1050  100            NaN
# 171  KMeans    5  0.746667  2.031250    1  1050  100            NaN
# 172  KMeans    6  0.780000  2.200855    1  1050  100            NaN
# 173  KMeans    7  0.800000  2.320833    1  1050  100            NaN
# 174  KMeans    8  0.820000  2.459350    1  1050  100            NaN
# 175  KMeans    9  0.836667  2.589641    1  1050  100            NaN
# 176  KMeans   10  0.846667  2.677165    1  1050  100            NaN
#
#      n_clusters algorithm  n_components  gini  p value hierarchy
# 167        45.0    KMeans           NaN   NaN      NaN      flat
# 168        45.0    KMeans           NaN   NaN      NaN      flat
# 169        45.0    KMeans           NaN   NaN      NaN      flat
# 170        45.0    KMeans           NaN   NaN      NaN      flat
# 171        45.0    KMeans           NaN   NaN      NaN      flat
# 172        45.0    KMeans           NaN   NaN      NaN      flat
# 173        45.0    KMeans           NaN   NaN      NaN      flat
# 174        45.0    KMeans           NaN   NaN      NaN      flat
# 175        45.0    KMeans           NaN   NaN      NaN      flat
# 176        45.0    KMeans           NaN   NaN      NaN      flat
# Empty DataFrame
# Columns: [Method, R_e, A@e, RA@e, Run, n, f, max info loss, n_clusters, algorithm, n_components, gini, p value, hierarchy]
# Index: []
#     Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 307  Birch    1  0.353333  1.000000    1  1050  100            NaN
# 308  Birch    2  0.553333  1.361446    1  1050  100            NaN
# 309  Birch    3  0.633333  1.568421    1  1050  100            NaN
# 310  Birch    4  0.710000  1.830986    1  1050  100            NaN
# 311  Birch    5  0.780000  2.115385    1  1050  100            NaN
# 312  Birch    6  0.823333  2.319838    1  1050  100            NaN
# 313  Birch    7  0.836667  2.394422    1  1050  100            NaN
# 314  Birch    8  0.853333  2.503906    1  1050  100            NaN
# 315  Birch    9  0.866667  2.603846    1  1050  100            NaN
# 316  Birch   10  0.893333  2.824627    1  1050  100            NaN
#
#      n_clusters algorithm  n_components  gini  p value hierarchy
# 307        20.0     Birch           NaN   NaN      NaN      flat
# 308        20.0     Birch           NaN   NaN      NaN      flat
# 309        20.0     Birch           NaN   NaN      NaN      flat
# 310        20.0     Birch           NaN   NaN      NaN      flat
# 311        20.0     Birch           NaN   NaN      NaN      flat
# 312        20.0     Birch           NaN   NaN      NaN      flat
# 313        20.0     Birch           NaN   NaN      NaN      flat
# 314        20.0     Birch           NaN   NaN      NaN      flat
# 315        20.0     Birch           NaN   NaN      NaN      flat
# 316        20.0     Birch           NaN   NaN      NaN      flat
#        Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 1877  SPH+CPI    1  0.340000  1.000000    1  1050  100           0.35
# 1878  SPH+CPI    2  0.516667  1.341935    1  1050  100           0.35
# 1879  SPH+CPI    3  0.606667  1.587912    1  1050  100           0.35
# 1880  SPH+CPI    4  0.673333  1.826733    1  1050  100           0.35
# 1881  SPH+CPI    5  0.733333  2.086364    1  1050  100           0.35
# 1882  SPH+CPI    6  0.753333  2.190265    1  1050  100           0.35
# 1883  SPH+CPI    7  0.783333  2.374468    1  1050  100           0.35
# 1884  SPH+CPI    8  0.793333  2.445378    1  1050  100           0.35
# 1885  SPH+CPI    9  0.813333  2.606557    1  1050  100           0.35
# 1886  SPH+CPI   10  0.816667  2.636735    1  1050  100           0.35
#
#       n_clusters algorithm  n_components  gini  p value hierarchy
# 1877         NaN       NaN           NaN   0.4      0.9      flat
# 1878         NaN       NaN           NaN   0.4      0.9      flat
# 1879         NaN       NaN           NaN   0.4      0.9      flat
# 1880         NaN       NaN           NaN   0.4      0.9      flat
# 1881         NaN       NaN           NaN   0.4      0.9      flat
# 1882         NaN       NaN           NaN   0.4      0.9      flat
# 1883         NaN       NaN           NaN   0.4      0.9      flat
# 1884         NaN       NaN           NaN   0.4      0.9      flat
# 1885         NaN       NaN           NaN   0.4      0.9      flat
# 1886         NaN       NaN           NaN   0.4      0.9      flat
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 2137    CPI    1  0.296667  1.000000    1  1050  100            NaN
# 2138    CPI    2  0.440000  1.325758    1  1050  100            NaN
# 2139    CPI    3  0.533333  1.618750    1  1050  100            NaN
# 2140    CPI    4  0.593333  1.859551    1  1050  100            NaN
# 2141    CPI    5  0.640000  2.088542    1  1050  100            NaN
# 2142    CPI    6  0.676667  2.300493    1  1050  100            NaN
# 2143    CPI    7  0.700000  2.457143    1  1050  100            NaN
# 2144    CPI    8  0.743333  2.780269    1  1050  100            NaN
# 2145    CPI    9  0.763333  2.943231    1  1050  100            NaN
# 2146    CPI   10  0.776667  3.064378    1  1050  100            NaN
#
#       n_clusters algorithm  n_components  gini  p value hierarchy
# 2137         NaN       NaN           NaN   0.2      0.7      flat
# 2138         NaN       NaN           NaN   0.2      0.7      flat
# 2139         NaN       NaN           NaN   0.2      0.7      flat
# 2140         NaN       NaN           NaN   0.2      0.7      flat
# 2141         NaN       NaN           NaN   0.2      0.7      flat
# 2142         NaN       NaN           NaN   0.2      0.7      flat
# 2143         NaN       NaN           NaN   0.2      0.7      flat
# 2144         NaN       NaN           NaN   0.2      0.7      flat
# 2145         NaN       NaN           NaN   0.2      0.7      flat
# 2146         NaN       NaN           NaN   0.2      0.7      flat
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 2386    SPH    1  0.366667  1.000000    1  1050  100           0.35
# 2387    SPH    2  0.550000  1.333333    1  1050  100           0.35
# 2388    SPH    3  0.653333  1.596939    1  1050  100           0.35
# 2389    SPH    4  0.720000  1.819444    1  1050  100           0.35
# 2390    SPH    5  0.756667  1.973568    1  1050  100           0.35
# 2391    SPH    6  0.766667  2.026087    1  1050  100           0.35
# 2392    SPH    7  0.783333  2.131915    1  1050  100           0.35
# 2393    SPH    8  0.793333  2.205882    1  1050  100           0.35
# 2394    SPH    9  0.806667  2.318182    1  1050  100           0.35
# 2395    SPH   10  0.816667  2.412245    1  1050  100           0.35
#
#       n_clusters algorithm  n_components  gini  p value hierarchy
# 2386         NaN       NaN           NaN   NaN      NaN    normal
# 2387         NaN       NaN           NaN   NaN      NaN    normal
# 2388         NaN       NaN           NaN   NaN      NaN    normal
# 2389         NaN       NaN           NaN   NaN      NaN    normal
# 2390         NaN       NaN           NaN   NaN      NaN    normal
# 2391         NaN       NaN           NaN   NaN      NaN    normal
# 2392         NaN       NaN           NaN   NaN      NaN    normal
# 2393         NaN       NaN           NaN   NaN      NaN    normal
# 2394         NaN       NaN           NaN   NaN      NaN    normal
# 2395         NaN       NaN           NaN   NaN      NaN    normal
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 2406     RF    1  0.306667  1.000000    1  1050  100            NaN
# 2407     RF    2  0.466667  1.342857    1  1050  100            NaN
# 2408     RF    3  0.570000  1.643275    1  1050  100            NaN
# 2409     RF    4  0.636667  1.890052    1  1050  100            NaN
# 2410     RF    5  0.703333  2.184834    1  1050  100            NaN
# 2411     RF    6  0.723333  2.290323    1  1050  100            NaN
# 2412     RF    7  0.750000  2.457778    1  1050  100            NaN
# 2413     RF    8  0.776667  2.648069    1  1050  100            NaN
# 2414     RF    9  0.790000  2.755274    1  1050  100            NaN
# 2415     RF   10  0.800000  2.845833    1  1050  100            NaN
#
#       n_clusters algorithm  n_components  gini  p value hierarchy
# 2406         NaN       NaN           NaN   NaN      NaN    normal
# 2407         NaN       NaN           NaN   NaN      NaN    normal
# 2408         NaN       NaN           NaN   NaN      NaN    normal
# 2409         NaN       NaN           NaN   NaN      NaN    normal
# 2410         NaN       NaN           NaN   NaN      NaN    normal
# 2411         NaN       NaN           NaN   NaN      NaN    normal
# 2412         NaN       NaN           NaN   NaN      NaN    normal
# 2413         NaN       NaN           NaN   NaN      NaN    normal
# 2414         NaN       NaN           NaN   NaN      NaN    normal
# 2415         NaN       NaN           NaN   NaN      NaN    normal
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 2416   RF+B    1  0.290000  1.000000    1  1050  100            NaN
# 2417   RF+B    2  0.446667  1.350746    1  1050  100            NaN
# 2418   RF+B    3  0.530000  1.610063    1  1050  100            NaN
# 2419   RF+B    4  0.610000  1.923497    1  1050  100            NaN
# 2420   RF+B    5  0.716667  2.381395    1  1050  100            NaN
# 2421   RF+B    6  0.733333  2.463636    1  1050  100            NaN
# 2422   RF+B    7  0.760000  2.622807    1  1050  100            NaN
# 2423   RF+B    8  0.783333  2.782979    1  1050  100            NaN
# 2424   RF+B    9  0.800000  2.912500    1  1050  100            NaN
# 2425   RF+B   10  0.816667  3.057143    1  1050  100            NaN
#
#       n_clusters algorithm  n_components  gini  p value hierarchy
# 2416         NaN       NaN           NaN   NaN      NaN    normal
# 2417         NaN       NaN           NaN   NaN      NaN    normal
# 2418         NaN       NaN           NaN   NaN      NaN    normal
# 2419         NaN       NaN           NaN   NaN      NaN    normal
# 2420         NaN       NaN           NaN   NaN      NaN    normal
# 2421         NaN       NaN           NaN   NaN      NaN    normal
# 2422         NaN       NaN           NaN   NaN      NaN    normal
# 2423         NaN       NaN           NaN   NaN      NaN    normal
# 2424         NaN       NaN           NaN   NaN      NaN    normal
# 2425         NaN       NaN           NaN   NaN      NaN    normal
#       Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 2446  KMeans    1  0.376667  1.000000    1  1050  100            NaN
# 2447  KMeans    2  0.530000  1.289308    1  1050  100            NaN
# 2448  KMeans    3  0.633333  1.568421    1  1050  100            NaN
# 2449  KMeans    4  0.683333  1.746341    1  1050  100            NaN
# 2450  KMeans    5  0.720000  1.912037    1  1050  100            NaN
# 2451  KMeans    6  0.753333  2.092920    1  1050  100            NaN
# 2452  KMeans    7  0.780000  2.260684    1  1050  100            NaN
# 2453  KMeans    8  0.793333  2.357143    1  1050  100            NaN
# 2454  KMeans    9  0.820000  2.573171    1  1050  100            NaN
# 2455  KMeans   10  0.833333  2.692000    1  1050  100            NaN
#
#       n_clusters algorithm  n_components  gini  p value hierarchy
# 2446        20.0    KMeans           NaN   NaN      NaN    normal
# 2447        20.0    KMeans           NaN   NaN      NaN    normal
# 2448        20.0    KMeans           NaN   NaN      NaN    normal
# 2449        20.0    KMeans           NaN   NaN      NaN    normal
# 2450        20.0    KMeans           NaN   NaN      NaN    normal
# 2451        20.0    KMeans           NaN   NaN      NaN    normal
# 2452        20.0    KMeans           NaN   NaN      NaN    normal
# 2453        20.0    KMeans           NaN   NaN      NaN    normal
# 2454        20.0    KMeans           NaN   NaN      NaN    normal
# 2455        20.0    KMeans           NaN   NaN      NaN    normal
# Empty DataFrame
# Columns: [Method, R_e, A@e, RA@e, Run, n, f, max info loss, n_clusters, algorithm, n_components, gini, p value, hierarchy]
# Index: []
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 2646  Birch    1  0.356667  1.000000    1  1050  100            NaN
# 2647  Birch    2  0.533333  1.331250    1  1050  100            NaN
# 2648  Birch    3  0.623333  1.572193    1  1050  100            NaN
# 2649  Birch    4  0.686667  1.796117    1  1050  100            NaN
# 2650  Birch    5  0.726667  1.972477    1  1050  100            NaN
# 2651  Birch    6  0.760000  2.149123    1  1050  100            NaN
# 2652  Birch    7  0.776667  2.253219    1  1050  100            NaN
# 2653  Birch    8  0.810000  2.489712    1  1050  100            NaN
# 2654  Birch    9  0.830000  2.646586    1  1050  100            NaN
# 2655  Birch   10  0.840000  2.734127    1  1050  100            NaN
#
#       n_clusters algorithm  n_components  gini  p value hierarchy
# 2646        20.0     Birch           NaN   NaN      NaN    normal
# 2647        20.0     Birch           NaN   NaN      NaN    normal
# 2648        20.0     Birch           NaN   NaN      NaN    normal
# 2649        20.0     Birch           NaN   NaN      NaN    normal
# 2650        20.0     Birch           NaN   NaN      NaN    normal
# 2651        20.0     Birch           NaN   NaN      NaN    normal
# 2652        20.0     Birch           NaN   NaN      NaN    normal
# 2653        20.0     Birch           NaN   NaN      NaN    normal
# 2654        20.0     Birch           NaN   NaN      NaN    normal
# 2655        20.0     Birch           NaN   NaN      NaN    normal
#        Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 4206  SPH+CPI    1  0.386667  1.000000    1  1050  100           0.35
# 4207  SPH+CPI    2  0.550000  1.296970    1  1050  100           0.35
# 4208  SPH+CPI    3  0.656667  1.573604    1  1050  100           0.35
# 4209  SPH+CPI    4  0.723333  1.797235    1  1050  100           0.35
# 4210  SPH+CPI    5  0.756667  1.938326    1  1050  100           0.35
# 4211  SPH+CPI    6  0.770000  2.008658    1  1050  100           0.35
# 4212  SPH+CPI    7  0.790000  2.135021    1  1050  100           0.35
# 4213  SPH+CPI    8  0.806667  2.256198    1  1050  100           0.35
# 4214  SPH+CPI    9  0.813333  2.311475    1  1050  100           0.35
# 4215  SPH+CPI   10  0.816667  2.342857    1  1050  100           0.35
#
#       n_clusters algorithm  n_components  gini  p value hierarchy
# 4206         NaN       NaN           NaN   0.4     0.85    normal
# 4207         NaN       NaN           NaN   0.4     0.85    normal
# 4208         NaN       NaN           NaN   0.4     0.85    normal
# 4209         NaN       NaN           NaN   0.4     0.85    normal
# 4210         NaN       NaN           NaN   0.4     0.85    normal
# 4211         NaN       NaN           NaN   0.4     0.85    normal
# 4212         NaN       NaN           NaN   0.4     0.85    normal
# 4213         NaN       NaN           NaN   0.4     0.85    normal
# 4214         NaN       NaN           NaN   0.4     0.85    normal
# 4215         NaN       NaN           NaN   0.4     0.85    normal
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 4486    CPI    1  0.300000  1.000000    1  1050  100            NaN
# 4487    CPI    2  0.446667  1.328358    1  1050  100            NaN
# 4488    CPI    3  0.546667  1.634146    1  1050  100            NaN
# 4489    CPI    4  0.606667  1.868132    1  1050  100            NaN
# 4490    CPI    5  0.666667  2.150000    1  1050  100            NaN
# 4491    CPI    6  0.686667  2.262136    1  1050  100            NaN
# 4492    CPI    7  0.720000  2.481481    1  1050  100            NaN
# 4493    CPI    8  0.756667  2.748899    1  1050  100            NaN
# 4494    CPI    9  0.773333  2.883621    1  1050  100            NaN
# 4495    CPI   10  0.790000  3.033755    1  1050  100            NaN
#
#       n_clusters algorithm  n_components  gini  p value hierarchy
# 4486         NaN       NaN           NaN   0.2     0.75    normal
# 4487         NaN       NaN           NaN   0.2     0.75    normal
# 4488         NaN       NaN           NaN   0.2     0.75    normal
# 4489         NaN       NaN           NaN   0.2     0.75    normal
# 4490         NaN       NaN           NaN   0.2     0.75    normal
# 4491         NaN       NaN           NaN   0.2     0.75    normal
# 4492         NaN       NaN           NaN   0.2     0.75    normal
# 4493         NaN       NaN           NaN   0.2     0.75    normal
# 4494         NaN       NaN           NaN   0.2     0.75    normal
# 4495         NaN       NaN           NaN   0.2     0.75    normal
#      Method  R_e       A@e      RA@e  Run     n    f  max info loss  \
# 0        RF    1  0.320000  1.000000    1  1050  100            NaN
# 1        RF    2  0.466667  1.314286    1  1050  100            NaN
# 2        RF    3  0.560000  1.595238    1  1050  100            NaN
# 3        RF    4  0.646667  1.917526    1  1050  100            NaN
# 4        RF    5  0.706667  2.179245    1  1050  100            NaN
# ...     ...  ...       ...       ...  ...   ...  ...            ...
# 4491    CPI    6  0.686667  2.262136    1  1050  100            NaN
# 4492    CPI    7  0.720000  2.481481    1  1050  100            NaN
# 4493    CPI    8  0.756667  2.748899    1  1050  100            NaN
# 4494    CPI    9  0.773333  2.883621    1  1050  100            NaN
# 4495    CPI   10  0.790000  3.033755    1  1050  100            NaN
#
#       n_clusters algorithm  n_components  gini  p value hierarchy
# 0            NaN       NaN           NaN   NaN      NaN      flat
# 1            NaN       NaN           NaN   NaN      NaN      flat
# 2            NaN       NaN           NaN   NaN      NaN      flat
# 3            NaN       NaN           NaN   NaN      NaN      flat
# 4            NaN       NaN           NaN   NaN      NaN      flat
# ...          ...       ...           ...   ...      ...       ...
# 4491         NaN       NaN           NaN   0.2     0.75    normal
# 4492         NaN       NaN           NaN   0.2     0.75    normal
# 4493         NaN       NaN           NaN   0.2     0.75    normal
# 4494         NaN       NaN           NaN   0.2     0.75    normal
# 4495         NaN       NaN           NaN   0.2     0.75    normal
#
# [139 rows x 14 columns]

# %%
ax = sns.relplot(data=best_result_df[best_result_df["Method"].isin(["SPH", "SPH+CPI", "RF", "CPI"])], x="R_e", y="A@e", hue="Method", col="hierarchy", kind="line", markers=True, style="Method",col_wrap=2)
ax.set(yticks=[0.05*i for i in range(5, 20)])

# %%
#ax = sns.relplot(data=best_result_df[best_result_df["Method"].isin(["SPH", "SPH+CPI", "RF", "CPI"])], x="R_e", y="A@e", hue="Method", col="hierarchy", kind="bar", markers=True, style="Method",col_wrap=2)
ax = sns.barplot(data=best_result_df[(best_result_df["R_e"] ==1) & (best_result_df["Method"].isin(["SPH", "SPH+CPI", "RF", "CPI"]))], x="hierarchy", y="A@e", hue="Method")
ax.set_ylabel("A@1")
# Out:
# Text(0, 0.5, 'A@1')

# %%
sns.relplot(data=best_result_df[best_result_df["Method"].isin(["SPH", "SPH+CPI", "RF", "KMeans", "Birch"])], x="R_e", y="A@e", hue="Method", style="Method", markers=True, col="hierarchy", kind="line", col_wrap=2)

# %%
ax = sns.barplot(data=best_result_df[(best_result_df["R_e"] <=10) & (best_result_df["Method"].isin(["SPH", "SPH+CPI", "RF", "KMeans", "Birch"]))], x="hierarchy", y="A@e", hue="Method")
ax.set_ylabel("A@1")
# Out:
# Text(0, 0.5, 'A@1')

# %%
best_parameter_df = pd.DataFrame()
for n in best_result_df["n"].unique():
    #print("--------------------------------------")
    #print(f"n={n}")
    best_n_samples = best_result_df[best_result_df["n"] == n]
    for method in best_n_samples["Method"].unique():
        param_df = best_n_samples[(best_n_samples["Method"] == method) & (best_n_samples["R_e"] == 1)][methods_to_parameters[method]]
        #print(f"Method {method} has best parameters:")
        #print(param_df)
        #print("--------------------------------------")
        param_df["Method"] = method
        param_df["n"] = n
        best_parameter_df = pd.concat([best_parameter_df, param_df])
    
best_parameter_df
# Out:
#        max info loss   Method      n  n_clusters  gini  p value
# 28              0.25      SPH    500         NaN   NaN      NaN
# 61               NaN       RF    500         NaN   NaN      NaN
# 71               NaN     RF+B    500         NaN   NaN      NaN
# 101              NaN   KMeans    500        20.0   NaN      NaN
# 371              NaN    Birch    500        50.0   NaN      NaN
# 1856            0.40  SPH+CPI    500         NaN  0.20     0.70
# 2086             NaN      CPI    500         NaN  0.20     0.70
# 2386            0.35      SPH   1050         NaN   NaN      NaN
# 2406             NaN       RF   1050         NaN   NaN      NaN
# 2416             NaN     RF+B   1050         NaN   NaN      NaN
# 2446             NaN   KMeans   1050        20.0   NaN      NaN
# 2646             NaN    Birch   1050        20.0   NaN      NaN
# 4206            0.35  SPH+CPI   1050         NaN  0.40     0.85
# 4486             NaN      CPI   1050         NaN  0.20     0.75
# 4746            0.20      SPH   2000         NaN   NaN      NaN
# 4796             NaN       RF   2000         NaN   NaN      NaN
# 4806             NaN     RF+B   2000         NaN   NaN      NaN
# 4856             NaN   KMeans   2000        26.0   NaN      NaN
# 5016             NaN    Birch   2000        10.0   NaN      NaN
# 5796            0.20  SPH+CPI   2000         NaN  0.35     0.85
# 6866             NaN      CPI   2000         NaN  0.20     0.70
# 7116            0.10      SPH   5000         NaN   NaN      NaN
# 7186             NaN       RF   5000         NaN   NaN      NaN
# 7196             NaN     RF+B   5000         NaN   NaN      NaN
# 7256             NaN   KMeans   5000        30.0   NaN      NaN
# 7456             NaN    Birch   5000        30.0   NaN      NaN
# 7706            0.10  SPH+CPI   5000         NaN  0.40     0.70
# 9266             NaN      CPI   5000         NaN  0.20     0.75
# 9506            0.10      SPH  10000         NaN   NaN      NaN
# 9576             NaN       RF  10000         NaN   NaN      NaN
# 9586             NaN     RF+B  10000         NaN   NaN      NaN
# 9606             NaN   KMeans  10000        15.0   NaN      NaN
# 9806             NaN    Birch  10000        15.0   NaN      NaN
# 10116           0.10  SPH+CPI  10000         NaN  0.40     0.80
# 11656            NaN      CPI  10000         NaN  0.20     0.75
