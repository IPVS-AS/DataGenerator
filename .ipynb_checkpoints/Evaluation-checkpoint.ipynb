# %%
from IPython.display import HTML
import random

def hide_toggle(for_next=False):
    this_cell = """$('div.cell.code_cell.rendered.selected')"""
    next_cell = this_cell + '.next()'

    toggle_text = 'Toggle show/hide'  # text shown on toggle link
    target_cell = this_cell  # target cell to control with toggle
    js_hide_current = ''  # bit of JS to permanently hide code in current cell (only when toggling next cell)

    if for_next:
        target_cell = next_cell
        toggle_text += ' next cell'
        js_hide_current = this_cell + '.find("div.input").hide();'

    js_f_name = 'code_toggle_{}'.format(str(random.randint(1,2**64)))

    html = """
        <script>
            function {f_name}() {{
                {cell_selector}.find('div.input').toggle();
            }}

            {js_hide_current}
        </script>

        <a href="javascript:{f_name}()">{toggle_text}</a>
    """.format(
        f_name=js_f_name,
        cell_selector=target_cell,
        js_hide_current=js_hide_current, 
        toggle_text=toggle_text
    )

    return HTML(html)
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
hide_toggle()
# Out:
#         <script>
#             function code_toggle_2088096061036137481() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_2088096061036137481()">Toggle show/hide</a>

# %%
import seaborn as sns
print(sns.__version__)
def add_median_labels(ax):
    import matplotlib.patheffects as path_effects

    lines = ax.get_lines()
    # determine number of lines per box (this varies with/without fliers)
    boxes = [c for c in ax.get_children() if type(c).__name__ == 'PathPatch']
    lines_per_box = int(len(lines) / len(boxes))
    # iterate over median lines
    for median in lines[4:len(lines):lines_per_box]:
        # display median value at center of median line
        x, y = (data.mean() for data in median.get_data())
        # choose value depending on horizontal or vertical plot orientation
        value = x if (median.get_xdata()[1] - median.get_xdata()[0]) == 0 else y
        text = ax.text(x, y, f'{value:.0f}', ha='center', va='center',
                       fontweight='bold', color='white')
        # create median-colored border around white text for contrast
        text.set_path_effects([
            path_effects.Stroke(linewidth=3, foreground=median.get_color()),
            path_effects.Normal(),
        ])

def add_avg_labels(ax):
    import matplotlib.patheffects as path_effects

    lines = ax.get_lines()
    # determine number of lines per box (this varies with/without fliers)
    boxes = [c for c in ax.get_children() if type(c).__name__ == 'PathPatch']
    lines_per_box = int(len(lines) / len(boxes))
    
    # iterate over median lines
    for median in lines[5:len(lines):lines_per_box]:
        # display median value at center of median line
        x, y = (data.mean() for data in median.get_data())
        # choose value depending on horizontal or vertical plot orientation
        value = x if (median.get_xdata()[1] - median.get_xdata()[0]) == 0 else y
        text = ax.text(x, y, f'{value:.2f}', ha='center', va='center',
                       fontweight='bold', color='white', bbox=dict(facecolor='#445A69'))
        # create median-colored border around white text for contrast
        text.set_path_effects([
            path_effects.Stroke(linewidth=3, foreground=median.get_color()),
            path_effects.Normal(),
        ])

hide_toggle()
# Out:
# 0.11.2
#         <script>
#             function code_toggle_2307514916834103651() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_2307514916834103651()">Toggle show/hide</a>

# %%
def adjust_group(row):
    if not pd.isna(row["group"]):
        return row["group"]
    
    if pd.isna(row["Unnamed: 0.1"]):
        return row["Unnamed: 0"]
    
    if pd.isna(row["Unnamed: 0"]):
        return row["Unnamed: 0.1"]
    
    else:
        return row["Unnamed: 0.1"]

stats_df = pd.read_csv("evaluation/stats.csv", sep=';', decimal=',', index_col=None)
preds = pd.read_csv("evaluation/predictions.csv", sep=';', decimal=',', index_col=None)
#print(preds.head())
preds["group"] = preds.apply(lambda row: adjust_group(row), axis=1)
#preds = preds.drop(["Unnamed: 0", "Unnamed: 0.1"], axis=1)
for column in ["accuracy", "F1", "prec", "recall"]:
    preds[column] = preds[column].astype(float)
#stats_df = stats_df.drop(["Unnamed: 0.1", "Unnamed: 0.1.1"], axis=1)
stats_df = stats_df[(stats_df["n"] == 1000) &
                    (stats_df["c"].isin( [10,20,30,40,50]))]
preds = preds[(preds["n"] == 1000)&
    (preds["c"].isin( [10,20,30,40,50]))]
measures = ["Border Points (C)", "NN Error (C)",  "Class Overlap (C)", "Inter/Intra Class Dist (C)", "Fishers DR (C)", "Gini (C)"]
for measure in measures:
    no_c = measure.replace(" (C)", "")
    stats_df[no_c] = stats_df[measure]
    stats_df = stats_df.drop(measure, axis=1)
stats_df.columns
hide_toggle()
# Out:
#         <script>
#             function code_toggle_11525306431799352465() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_11525306431799352465()">Toggle show/hide</a>

# %% [markdown]
# # Ensure Multi-Class Imbalance (C1)

# %% [markdown]
# ## Prepare Measures to Use
# Metrics: Complexity Measures from Feature Overlap (F1 and F2), and from neighborhood based (N1 - N3) and the Gini Coefficient.
#
# Parameters: "c" and "s_C".

# %%
c1_parameters = ["c", "cls_imbalance"]
c1_measures = ["Fishers DR","Border Points", "NN Error"]
complexity_measures_df = stats_df[c1_parameters + c1_measures]
hide_toggle()
# Out:
#         <script>
#             function code_toggle_6742934966956567236() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_6742934966956567236()">Toggle show/hide</a>

# %%
c1_melt_df = complexity_measures_df.melt(c1_parameters, var_name="Measure", value_name="Value of Measure")
c1_melt_df["Value of Measure"] = c1_melt_df["Value of Measure"].astype(float)
hide_toggle()
# Out:
#         <script>
#             function code_toggle_8361189308543313966() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_8361189308543313966()">Toggle show/hide</a>

# %%
x_labels = {'cls_imbalance': r'Class Imbalance ($s_C$)'}
x_value = 'c'
plt.figure()
ax = sns.lineplot(data=c1_melt_df, x=x_value, y="Value of Measure", hue="Measure", style="Measure", ci=None, alpha=0.7, markers=True)
#ax.invert_yaxis()
plt.legend(bbox_to_anchor=(-0.1, -0.3), ncol=5, loc="center left", title="Complexity Measures") 
ax.set_xticks(c1_melt_df[x_value].unique())
ax.set_xlabel(x_labels[x_value])
#ax.set_ylabel("Complexity Measure Value")
ax.set_ylim([-0.02,1.0])
plt.legend(bbox_to_anchor=(-0.1, -0.3), ncol=7, loc="center left", title="Complexity Measures")
#plt.show()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig(f"evaluation/Figures/C1_{x_value}_measures.pdf", bbox_inches='tight')
hide_toggle()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-c40df306c4e7> in <module>
#       6 plt.legend(bbox_to_anchor=(-0.1, -0.3), ncol=5, loc="center left", title="Complexity Measures")
#       7 ax.set_xticks(c1_melt_df[x_value].unique())
# ----> 8 ax.set_xlabel(x_labels[x_value])
#       9 #ax.set_ylabel("Complexity Measure Value")
#      10 ax.set_ylim([-0.02,1.0])
#
# KeyError: 'c'

# %% [markdown]
# ### Observations for c:
# - NN Error und Borderpoints steigen mit Anzahl Klassen. Ist logisch, weil je mehr Klassen ich habe, ergeben sich automatisch mehr Abgrenzungen zwischen den Klassen, d.h., mehr Punkte die von verschiedenen Klassen aneinander grenzen. Es wird ja dieselbe Anzahl an Samples auf mehr Klassen verteilen.
# - Class Overlap sinkt [???] Hätte erwartet, dass man auch mehr Klassenüberschneidungen haben sollte. Ist allerdings eher "Feature" als "Klassen" Overlap.
# - Gini Index steigt von 10 auf 20, ist dann aber recht konstant.

# %%
x_value = 'cls_imbalance'
plt.figure()
ax = sns.lineplot(data=c1_melt_df, x=x_value, y="Value of Measure", hue="Measure", style="Measure", ci=None, alpha=0.7, markers=True)
#ax.invert_yaxis()
plt.legend(ncol=5, loc="upper left", title="Complexity Measures") 
ax.set_xticklabels(["Very Balanced","Balanced","Medium","Imbalanced", "Very Imbalanced"], rotation=30)
ax.set_xlabel(x_labels[x_value])
#ax.set_ylabel("Complexity Measure Value")
ax.set_ylim([-0.02,1.0])
#plt.show()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig(f"evaluation/Figures/C1_{x_value}_measures.pdf", bbox_inches='tight')
hide_toggle()
# Out:
# <ipython-input-47-4540b79d7c45>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(["Very Balanced","Balanced","Medium","Imbalanced", "Very Imbalanced"], rotation=30)
#         <script>
#             function code_toggle_11353139490607003143() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_11353139490607003143()">Toggle show/hide</a>

# %% [markdown]
# ### Observations for Class Imbalance ($s_c$):
#
# - Gini Koeffizient steigt. War zu erwarten, da wir zwar pro Gruppe die Class imbalance erhöhen, das sich aber eben auch auf den ganzen Datensatz auswirkt. Je nach Anzahl der Gruppen, ist es jedoch schwierig den Gini Index auf dem gesamten Datensatz sehr hoch zu bringen. Je mehr Gruppen wir haben, desto limitierter ist der Gini Koeffizient.
# - Borderpoints und NN Error sinken, was logisch ist, da wir weniger Instanzen von bestimmten Klassen haben bzw. manche Klassen jetzt mehr Instanzen haben. Dadurch ergeben sich weniger Borderpoints von verschiedenen Klassen.
# - Fishers DR steigt an. Das bedeutet Klassen sind leichter über Features zu separieren. Passt zu den Borderline Points!

# %% [markdown]
# ## Gini

# %%
stats_df.groupby("cls_imbalance")["Gini"].mean()
# Out:
# cls_imbalance
# balanced           0.326481
# imbalanced         0.549064
# medium             0.375416
# very_balanced      0.322841
# very_imbalanced    0.592613
# Name: Gini, dtype: float64

# %% [markdown]
# # Ensure Group Imbalance (C2a)
#
# Metrics: Gini Coefficient for the groups and statistics about the number of samples and classes for the different groups.
#
# Parameters: $s_G$.

# %%
# Load Gini Data 
group_gini_df = pd.read_csv("gini_groups.csv", sep=';', decimal=',', index_col=None)

# Prepare Statistics
group_stats = stats_df[["min #n groups", "avg #n groups", "max #n groups", "group_imbalance"]]
hide_toggle()
# Out:
#         <script>
#             function code_toggle_6131241147036648736() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_6131241147036648736()">Toggle show/hide</a>

# %%
group_stats_melt = group_stats.melt(['group_imbalance'], var_name='Aggregation', value_name='#n')
group_stats_melt["group_imbalance"] = pd.Categorical(group_stats_melt["group_imbalance"], categories=["very_balanced", "balanced", "medium", "imbalanced", "very_imbalanced"], ordered=True)
hide_toggle()
# Out:
#         <script>
#             function code_toggle_4138096777276342978() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_4138096777276342978()">Toggle show/hide</a>

# %%
def show_values_on_bars(axs, rotate=False):
    def _show_on_single_plot(ax):        
        for p in ax.patches:
            _x = p.get_x() + p.get_width() / 2
            _y = p.get_y() + p.get_height() + 10
            value = '{:.0f}'.format(p.get_height())
            ax.text(_x, _y, value, ha="center", fontsize="large", rotation=90) 

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)
        
fig = plt.figure()
ax = sns.barplot(data=group_stats_melt, x="group_imbalance", y="#n", hue="Aggregation", ci=None)
show_values_on_bars(ax)
ax.set_xticklabels(["Very Balanced","Balanced","Medium","Imbalanced", "Very Imbalanced"], rotation=30)
ax.set_ylabel("#Instances (n) for groups")
ax.set_ylim(0, 500)
ax.legend(labels=["min", "avg", "max"], title="Aggregation")
ax.set_xlabel(r"Group Imbalance ($s_G$)")
ax = plt.twinx()
ax2 = sns.lineplot(data=group_gini_df, x="group_imbalance", y="Gini (G)", color='r', marker="o", ax=ax, legend='brief', label="Gini (G)")
ax2.set_ylim(0, 0.8)
ax2.legend(loc="upper center")
ax2.set_ylabel("Gini Coefficient")
fig.savefig("evaluation/Figures/C2a_Group_imbalance.pdf", bbox_inches='tight')
hide_toggle()
# Out:
#         <script>
#             function code_toggle_2102189703355462297() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_2102189703355462297()">Toggle show/hide</a>

# %% [markdown]
# # Ensurance of Group Heterogeneity (C2b)
#
# Metrics: Complexity Measures per Group, Accuracy Difference
#
# Parameters: GS (Group separation), missing features, #characteris. Features

# %%
# Load the data 
stat_heter_df = pd.read_csv("evaluation/stats_heterogeneity.csv", sep=';', decimal=',', index_col=None)
# hide_toggle()
print(stat_heter_df.columns)
stat_heter_df[["Fishers DR (C)", "Fishers DR (G)", "gs", "n_group_features"]]
# Out:
# Index(['Unnamed: 0', 'avg #n classes+groups', 'min #n classes+groups',
#        'max #n classes+groups', 'avg #n groups', 'min #n groups',
#        'max #n groups', 'avg #c groups', 'min #c groups', 'max #c groups',
#        'Fishers DR (C)', 'Fishers DRv (C)', 'Class Overlap (C)',
#        'Border Points (C)', 'Inter/Intra Class Dist (C)', 'NN Error (C)',
#        'Fishers DR (G)', 'Fishers DRv (G)', 'Class Overlap (G)',
#        'Border Points (G)', 'Inter/Intra Class Dist (G)', 'NN Error (G)',
#        'Acc (X)', 'Acc (G)', 'Acc (G - X)', 'n', 'c', 'gs',
#        'features_remove_percent', 'n_group_features', 'group_imbalance',
#        'cls_imbalance', 'n_features'],
#       dtype='object')
#      Fishers DR (C)  Fishers DR (G)   gs  n_group_features
# 0          0.980565        0.942643  0.0                 1
# 1          0.980530        0.942854  0.0                 1
# 2          0.979649        0.941397  0.0                 1
# 3          0.978398        0.975059  0.0                 1
# 4          0.977272        0.972352  0.0                 1
# ..              ...             ...  ...               ...
# 410        0.370097        0.828801  1.0                20
# 411        0.789556        0.838837  1.0                 1
# 412        0.527406        0.838837  1.0                 5
# 413        0.415433        0.838837  1.0                10
# 414        0.388427        0.838837  1.0                20
#
# [415 rows x 4 columns]

# %%
c2b_parameters = ["gs", "n_group_features"]
parameter_mapping = {"gs": "Group separation (GS)", "n_group_features": "#charact. Features (CF)"}
c2b_measures = ["Fishers DR","Border Points", "NN Error"]

for measure in c2b_measures:
    c_measure = measure + " (C)"
    stat_heter_df[c_measure] = stat_heter_df[c_measure].astype(float)
    stat_heter_df[measure] = stat_heter_df[measure + " (G)"] - stat_heter_df[c_measure]
complexity_measures_df = stat_heter_df[c2b_parameters + c2b_measures]
hide_toggle()
# Out:
#         <script>
#             function code_toggle_2981395720907978959() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_2981395720907978959()">Toggle show/hide</a>

# %%
group_diff_cms_df = complexity_measures_df.melt(c2b_parameters, var_name='Measure', value_name='Measure Values')
hide_toggle()
# Out:
#         <script>
#             function code_toggle_1675372718538316425() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_1675372718538316425()">Toggle show/hide</a>

# %%
for parameter in c2b_parameters:
    plt.figure()
    ax = sns.lineplot(data=group_diff_cms_df, x=parameter, y="Measure Values", hue="Measure", style="Measure", ci=None, alpha=0.7, markers=True)
    ax.set_xticks(group_diff_cms_df[parameter].unique())
    ax.set_xlabel(parameter_mapping[parameter])
    ax.set_ylim(-0.4, 0.4)
    ax.set_ylabel(r"$\Delta$ Values (G - $\mathcal{X}$)")
    plt.legend(bbox_to_anchor=(-0.1, -0.3), ncol=7, loc="center left", title="Complexity Measures")
    #plt.show()
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    plt.savefig(f"evaluation/Figures/C2b_{parameter}_measures.pdf", bbox_inches='tight')
hide_toggle()
# Out:
#         <script>
#             function code_toggle_13318831353735377159() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_13318831353735377159()">Toggle show/hide</a>

# %% [markdown]
# ## Observations
# - Zunächst mal ist das Durchschnitt über Gruppen, nicht (!) gewichtet nach n
# - Generell: Bei gs=0 bzw. n_group_features=1, haben alle Unterschiede, d.h. Werte <> 0. Dnach steigen so gut wie alle Kurven an.
# - Fishers DR klarer Trend erkennbar. Steigt an für gs/n_group_features. Interessant ist, dass bei C1 hier ein umgekehrter Trend zu erkennen war, verglichen mit Borderpoints/NN Error.
# - Komisch ist, dass feature_remove_percent kein wirklicher Trend erkennbar ist. Scheint anzusteigen aber sinkt dann auch wieder.

# %%
acc_df = stat_heter_df[c2b_parameters + ['Acc (G)', 'Acc (X)', 'Acc (G - X)']]
acc_df = acc_df.melt(c2b_parameters, var_name='Accuracy Type', value_name='Accuracy')
hide_toggle()
# Out:
#         <script>
#             function code_toggle_14662547147786743440() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_14662547147786743440()">Toggle show/hide</a>

# %%
for parameter in c2b_parameters:
    plt.figure()
    ax = sns.lineplot(data=acc_df, x=parameter, y="Accuracy", hue="Accuracy Type", style="Accuracy Type", ci=None, alpha=0.7, markers=True)
    ax.set_xticks(acc_df[parameter].unique())
    ax.set_ylim(-0.02, 0.6)
    ax.set_xlabel(parameter_mapping[parameter])

    ax.set_ylabel(r"Accuracy")
    plt.legend(bbox_to_anchor=(-0.1, -0.3), ncol=7, loc="center left", labels=[r"One Model per Group ($G$)",  r"One Model for entire Data ($\mathcal{X}$)", r"$\Delta$Accuracy ($G$ - $\mathcal{X}$)"])
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    plt.savefig(f"evaluation/Figures/C2b_accuracy_{parameter}.pdf", bbox_inches='tight')
hide_toggle()
# Out:
#         <script>
#             function code_toggle_6773574352608008643() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_6773574352608008643()">Toggle show/hide</a>

# %% [markdown]
# # Accuracy for group size

# %% [markdown]
# ![Screenshot%202022-04-14%20095732.png](attachment:Screenshot%202022-04-14%20095732.png)
